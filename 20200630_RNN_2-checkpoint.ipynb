# %% [markdown]
# # Bidirectional RNN
# 양방향
# 문장이 길어지면 기억을 까먹는다(Vanishing problem).
# 오른쪽으로 다음 뉴런에 정보 전달하고
# 또 왼쪽으로 다시 돌아가서 기억을 더듬는다.

# %%
# !pip install tensorflow_datasets
# Out:
# Collecting tensorflow_datasets
#   Downloading tensorflow_datasets-3.1.0-py3-none-any.whl (3.3 MB)
# Requirement already satisfied: protobuf>=3.6.1 in c:\users\sundooedu\anaconda3\lib\site-packages (from tensorflow_datasets) (3.12.2)
# Collecting promise
#   Downloading promise-2.3.tar.gz (19 kB)
# Requirement already satisfied: absl-py in c:\users\sundooedu\anaconda3\lib\site-packages (from tensorflow_datasets) (0.9.0)
# Requirement already satisfied: numpy in c:\users\sundooedu\anaconda3\lib\site-packages (from tensorflow_datasets) (1.16.4)
# Requirement already satisfied: termcolor in c:\users\sundooedu\anaconda3\lib\site-packages (from tensorflow_datasets) (1.1.0)
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-0.22.2-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: tqdm in c:\users\sundooedu\anaconda3\lib\site-packages (from tensorflow_datasets) (4.32.1)
# Requirement already satisfied: attrs>=18.1.0 in c:\users\sundooedu\anaconda3\lib\site-packages (from tensorflow_datasets) (19.1.0)
# Requirement already satisfied: six in c:\users\sundooedu\anaconda3\lib\site-packages (from tensorflow_datasets) (1.12.0)
# Collecting dill
#   Downloading dill-0.3.2.zip (177 kB)
# Requirement already satisfied: future in c:\users\sundooedu\anaconda3\lib\site-packages (from tensorflow_datasets) (0.17.1)
# Requirement already satisfied: wrapt in c:\users\sundooedu\anaconda3\lib\site-packages (from tensorflow_datasets) (1.11.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\sundooedu\anaconda3\lib\site-packages (from tensorflow_datasets) (2.22.0)
# Requirement already satisfied: setuptools in c:\users\sundooedu\anaconda3\lib\site-packages (from protobuf>=3.6.1->tensorflow_datasets) (41.0.1)
# Collecting googleapis-common-protos
#   Downloading googleapis_common_protos-1.52.0-py2.py3-none-any.whl (100 kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\sundooedu\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\sundooedu\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sundooedu\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\sundooedu\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2.8)
# Building wheels for collected packages: promise, dill
#   Building wheel for promise (setup.py): started
#   Building wheel for promise (setup.py): finished with status 'done'
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21499 sha256=628fb98d641383a8a7f528f51668c4910dba7a6a56798b23a71663e60014fd92
#   Stored in directory: c:\users\sundooedu\appdata\local\pip\cache\wheels\29\93\c6\762e359f8cb6a5b69c72235d798804cae523bbe41c2aa8333d
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78977 sha256=e5358e8bbaf0c3237068f1a55ea3b7bbb7586511bf4bcf5346a230b18edfa1e8
#   Stored in directory: c:\users\sundooedu\appdata\local\pip\cache\wheels\72\6b\d5\5548aa1b73b8c3d176ea13f9f92066b02e82141549d90e2100
# Successfully built promise dill
# Installing collected packages: promise, googleapis-common-protos, tensorflow-metadata, dill, tensorflow-datasets
# Successfully installed dill-0.3.2 googleapis-common-protos-1.52.0 promise-2.3 tensorflow-datasets-3.1.0 tensorflow-metadata-0.22.2

# %%
import tensorflow_datasets as tfds
dataset, info = tfds.load('imdb_reviews/subwords8k', 
                          with_info=True,
                          as_supervised=True)
# Out:
# WARNING:absl:TFDS datasets with text encoding are deprecated and will be removed in a future version. Instead, you should use the plain text version and tokenize the text using `tensorflow_text` (See: https://www.tensorflow.org/tutorials/tensorflow_text/intro#tfdata_example)

# %%
train_dataset, test_dataset = dataset['train'], dataset['test']

# %%
encoder = info.features['text'].encoder

# %%
print(encoder.vocab_size, encoder.subwords)
# Out:
# 8185 ['the_', ', ', '. ', 'a_', 'and_', 'of_', 'to_', 's_', 'is_', 'br', 'in_', 'I_', 'that_', 'this_', 'it_', ' /><', ' />', 'was_', 'The_', 'as_', 't_', 'with_', 'for_', '.<', 'on_', 'but_', 'movie_', ' (', 'are_', 'his_', 'have_', 'film_', 'not_', 'ing_', 'be_', 'ed_', 'you_', ' "', 'it', 'd_', 'an_', 'he_', 'by_', 'at_', 'one_', 'who_', 'y_', 'from_', 'e_', 'or_', 'all_', 'like_', 'they_', '" ', 'so_', 'just_', 'has_', ') ', 'her_', 'about_', 'out_', 'This_', 'some_', 'ly_', 'movie', 'film', 'very_', 'more_', 'It_', 'would_', 'what_', 'when_', 'which_', 'good_', 'if_', 'up_', 'only_', 'even_', 'their_', 'had_', 'really_', 'my_', 'can_', 'no_', 'were_', 'see_', 'she_', '? ', 'than_', '! ', 'there_', 'get_', 'been_', 'into_', ' - ', 'will_', 'much_', 'story_', 'because_', 'ing', 'time_', 'n_', 'we_', 'ed', 'me_', ': ', 'most_', 'other_', 'don', 'do_', 'm_', 'es_', 'how_', 'also_', 'make_', 'its_', 'could_', 'first_', 'any_', "' ", 'people_', 'great_', 've_', 'ly', 'er_', 'made_', 'r_', 'But_', 'think_', " '", 'i_', 'bad_', 'A_', 'And_', 'It', 'on', '; ', 'him_', 'being_', 'never_', 'way_', 'that', 'many_', 'then_', 'where_', 'two_', 'In_', 'after_', 'too_', 'little_', 'you', '), ', 'well_', 'ng_', 'your_', 'If_', 'l_', '). ', 'does_', 'ever_', 'them_', 'did_', 'watch_', 'know_', 'seen_', 'time', 'er', 'character_', 'over_', 'characters_', 'movies_', 'man_', 'There_', 'love_', 'best_', 'still_', 'off_', 'such_', 'in', 'should_', 'the', 're_', 'He_', 'plot_', 'films_', 'go_', 'these_', 'acting_', 'doesn', 'es', 'show_', 'through_', 'better_', 'al_', 'something_', 'didn', 'back_', 'those_', 'us_', 'less_', '...', 'say_', 'is', 'one', 'makes_', 'and', 'can', 'all', 'ion_', 'find_', 'scene_', 'old_', 'real_', 'few_', 'going_', 'well', 'actually_', 'watching_', 'life_', 'me', '. <', 'o_', 'man', 'there', 'scenes_', 'same_', 'he', 'end_', 'this', '... ', 'k_', 'while_', 'thing_', 'of', 'look_', 'quite_', 'out', 'lot_', 'want_', 'why_', 'seems_', 'every_', 'll_', 'pretty_', 'got_', 'able_', 'nothing_', 'good', 'As_', 'story', ' & ', 'another_', 'take_', 'to', 'years_', 'between_', 'give_', 'am_', 'work_', 'isn', 'part_', 'before_', 'actors_', 'may_', 'gets_', 'young_', 'down_', 'around_', 'ng', 'thought_', 'though_', 'end', 'without_', 'What_', 'They_', 'things_', 'life', 'always_', 'must_', 'cast_', 'almost_', 'h_', '10', 'saw_', 'own_', 'here', 'bit_', 'come_', 'both_', 'might_', 'g_', 'whole_', 'new_', 'director_', 'them', 'horror_', 'ce', 'You_', 'least_', 'bad', 'big_', 'enough_', 'him', 'feel_', 'probably_', 'up', 'here_', 'making_', 'long_', 'her', 'st_', 'kind_', '--', 'original_', 'fact_', 'rather_', 'or', 'far_', 'nt_', 'played_', 'found_', 'last_', 'movies', 'When_', 'so', '", ', 'comes_', 'action_', 'She_', 've', 'our_', 'anything_', 'funny_', 'ion', 'right_', 'way', 'trying_', 'now_', 'ous_', 'each_', 'done_', 'since_', 'ic_', 'point_', '". ', 'wasn', 'interesting_', 'c_', 'worst_', 'te_', 'le_', 'ble_', 'ty_', 'looks_', 'show', 'put_', 'looking_', 'especially_', 'believe_', 'en_', 'goes_', 'over', 'ce_', 'p_', 'films', 'hard_', 'main_', 'be', 'having_', 'ry', 'TV_', 'worth_', 'One_', 'do', 'al', 're', 'again', 'series_', 'takes_', 'guy_', 'family_', 'seem_', 'plays_', 'role_', 'away_', 'world_', 'My_', 'character', ', "', 'performance_', '2_', 'So_', 'watched_', 'John_', 'th_', 'plot', 'script_', 'For_', 'sure_', 'characters', 'set_', 'different_', 'minutes_', 'All_', 'American_', 'anyone_', 'Not_', 'music_', 'ry_', 'shows_', 'too', 'son_', 'en', 'day_', 'use_', 'someone_', 'for', 'woman_', 'yet_', '." ', 'during_', 'she', 'ro', '- ', 'times_', 'left_', 'used_', 'le', 'three_', 'play_', 'work', 'ness_', 'We_', 'girl_', 'comedy_', 'ment_', 'an', 'simply_', 'off', 'ies_', 'funny', 'ne', 'acting', 'That_', 'fun_', 'completely_', 'st', 'seeing_', 'us', 'te', 'special_', 'ation_', 'as', 'ive_', 'ful_', 'read_', 'reason_', 'co', 'need_', 'sa', 'true_', 'ted_', 'like', 'ck', 'place_', 'they', '10_', 'However', 'until_', 'rest ...

# %%
encoded_string = encoder.encode('Hello Tensorflow.')

# %%
encoder.decode(encoded_string)
# Out:
# 'Hello Tensorflow.'

# %%
# accuracy는 의미가 없다
# loss이 의미가 있음. 낮아져야 좋은 모델이다.
# classification_report를 봐야 정확히 알아야 한다.

# %% [markdown]
# # Bidirectional RNN

# %%
# # ❖ 함께 하기(IMDB/subwords8k 사용)


BUFFER_SIZE = 10000; 
BATCH_SIZE = 64;
train_dataset = train_dataset.shuffle(BUFFER_SIZE)
train_dataset = train_dataset.padded_batch(BATCH_SIZE)
# 위는 연산속도 향상 위한 과정
# BATCH, 데이타 끊김 없이 만들어주는 옵션(GPU 사용 해야 함)


import tensorflow as tf
from tensorflow.keras import layers
model = tf.keras.Sequential([
layers.Embedding(encoder.vocab_size, 64),
layers.Bidirectional(layers.LSTM(64, return_sequences=True)),  # return, true 옵션을 줘야 밑에가 받을 수 있음
layers.Bidirectional(layers.LSTM(64, return_sequences=True)),
layers.Dense(64, activation='relu'),
layers.Dense(1)])
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(lr=1e-4), 
              metrics=['accuracy'])

hist = model.fit((train_dataset), epochs=2)
# train_dataset = (X, Y) 순서대로 튜플로 묶임
pred_text = ('The movie was cool. would recommend this movie.')
pred_text = encoder.encode(pred_text)

model.predict(tf.expand_dims(pred_text, axis=0)) #Returns a tensor
# model.input 
# [pred_text, axis=0] 차원 맞추기
# Out:
# Epoch 1/2
# 178/391 [============>.................] - ETA: 0s - loss: 0.6931 - accuracy: 0.53 - ETA: 13:21 - loss: 0.6929 - accuracy: 0.546 - ETA: 26:17 - loss: 0.6934 - accuracy: 0.510 - ETA: 29:56 - loss: 0.6936 - accuracy: 0.496 - ETA: 31:57 - loss: 0.6933 - accuracy: 0.509 - ETA: 30:16 - loss: 0.6935 - accuracy: 0.497 - ETA: 29:43 - loss: 0.6935 - accuracy: 0.493 - ETA: 30:32 - loss: 0.6936 - accuracy: 0.476 - ETA: 31:09 - loss: 0.6936 - accuracy: 0.480 - ETA: 35:41 - loss: 0.6935 - accuracy: 0.498 - ETA: 36:30 - loss: 0.6935 - accuracy: 0.490 - ETA: 37:18 - loss: 0.6935 - accuracy: 0.489 - ETA: 36:15 - loss: 0.6934 - accuracy: 0.496 - ETA: 36:45 - loss: 0.6934 - accuracy: 0.495 - ETA: 37:29 - loss: 0.6934 - accuracy: 0.502 - ETA: 37:50 - loss: 0.6934 - accuracy: 0.502 - ETA: 36:48 - loss: 0.6933 - accuracy: 0.498 - ETA: 36:24 - loss: 0.6933 - accuracy: 0.502 - ETA: 36:28 - loss: 0.6933 - accuracy: 0.500 - ETA: 35:58 - loss: 0.6933 - accuracy: 0.500 - ETA: 36:06 - loss: 0.6933 - accuracy: 0.499 - ETA: 35:46 - loss: 0.6933 - accuracy: 0.497 - ETA: 35:49 - loss: 0.6933 - accuracy: 0.501 - ETA: 35:00 - loss: 0.6933 - accuracy: 0.500 - ETA: 34:45 - loss: 0.6933 - accuracy: 0.501 - ETA: 34:12 - loss: 0.6933 - accuracy: 0.498 - ETA: 33:55 - loss: 0.6933 - accuracy: 0.497 - ETA: 33:14 - loss: 0.6933 - accuracy: 0.497 - ETA: 33:01 - loss: 0.6932 - accuracy: 0.493 - ETA: 33:20 - loss: 0.6932 - accuracy: 0.496 - ETA: 33:23 - loss: 0.6933 - accuracy: 0.499 - ETA: 33:11 - loss: 0.6933 - accuracy: 0.500 - ETA: 34:15 - loss: 0.6932 - accuracy: 0.496 - ETA: 33:51 - loss: 0.6932 - accuracy: 0.495 - ETA: 33:23 - loss: 0.6932 - accuracy: 0.496 - ETA: 33:11 - loss: 0.6932 - accuracy: 0.495 - ETA: 32:38 - loss: 0.6933 - accuracy: 0.498 - ETA: 32:44 - loss: 0.6932 - accuracy: 0.492 - ETA: 32:22 - loss: 0.6932 - accuracy: 0.490 - ETA: 32:14 - loss: 0.6932 - accuracy: 0.490 - ETA: 32:16 - loss: 0.6932 - accuracy: 0.490 - ETA: 31:58 - loss: 0.6932 - accuracy: 0.491 - ETA: 31:29 - loss: 0.6932 - accuracy: 0.492 - ETA: 31:07 - loss: 0.6932 - accuracy: 0.492 - ETA: 31:24 - loss: 0.6933 - accuracy: 0.495 - ETA: 31:30 - loss: 0.6933 - accuracy: 0.496 - ETA: 31:22 - loss: 0.6932 - accuracy: 0.494 - ETA: 31:12 - loss: 0.6933 - accuracy: 0.495 - ETA: 30:52 - loss: 0.6932 - accuracy: 0.495 - ETA: 31:20 - loss: 0.6932 - accuracy: 0.495 - ETA: 30:57 - loss: 0.6932 - accuracy: 0.495 - ETA: 30:52 - loss: 0.6933 - accuracy: 0.497 - ETA: 30:53 - loss: 0.6932 - accuracy: 0.496 - ETA: 30:48 - loss: 0.6932 - accuracy: 0.496 - ETA: 30:52 - loss: 0.6933 - accuracy: 0.498 - ETA: 30:37 - loss: 0.6933 - accuracy: 0.498 - ETA: 30:54 - loss: 0.6933 - accuracy: 0.500 - ETA: 30:45 - loss: 0.6933 - accuracy: 0.501 - ETA: 30:39 - loss: 0.6933 - accuracy: 0.500 - ETA: 30:44 - loss: 0.6933 - accuracy: 0.500 - ETA: 31:47 - loss: 0.6933 - accuracy: 0.500 - ETA: 31:48 - loss: 0.6933 - accuracy: 0.501 - ETA: 31:38 - loss: 0.6933 - accuracy: 0.502 - ETA: 31:35 - loss: 0.6933 - accuracy: 0.502 - ETA: 31:21 - loss: 0.6932 - accuracy: 0.501 - ETA: 31:06 - loss: 0.6932 - accuracy: 0.501 - ETA: 30:55 - loss: 0.6933 - accuracy: 0.500 - ETA: 30:48 - loss: 0.6933 - accuracy: 0.500 - ETA: 30:38 - loss: 0.6932 - accuracy: 0.502 - ETA: 30:29 - loss: 0.6932 - accuracy: 0.503 - ETA: 30:10 - loss: 0.6932 - accuracy: 0.502 - ETA: 30:15 - loss: 0.6932 - accuracy: 0.503 - ETA: 30:18 - loss: 0.6932 - accuracy: 0.503 - ETA: 30:16 - loss: 0.6932 - accuracy: 0.503 - ETA: 30:10 - loss: 0.6932 - accuracy: 0.502 - ETA: 29:54 - loss: 0.6932 - accuracy: 0.503 - ETA: 29:59 - loss: 0.6932 - accuracy: 0.503 - ETA: 29:51 - loss: 0.6932 - accuracy: 0.504 - ETA: 29:45 - loss: 0.6932 - accuracy: 0.504 - ETA: 29:40 - loss: 0.6932 - accuracy: 0.504 - ETA: 29:29 - loss: 0.6932 - accuracy: 0.505 - ETA: 29:11 - loss: 0.6932 - accuracy: 0.505 - ETA: 29:18 - loss: 0.6932 - accuracy: 0.504 - ETA: 29:10 - loss: 0.6931 - accuracy: 0.505 - ETA: 29:21 - loss: 0.6931 - accuracy: 0.507 - ETA: 29:05 - loss: 0.6931 - accuracy: 0.507 - ETA:  ...

# %%
pred_text

# %%
model.input

# %%
train_dataset
# Out:
# <PaddedBatchDataset shapes: ((None, None, None), (None, None)), types: (tf.int64, tf.int64)>

# %%
# tensorflow datasets 속도 때문, GPU 지원(CPU는 끊김 현상)
# pandas < numpy < tensorflow : 속도 더 빨라짐(연산속도 증가)

# %% [markdown]
# # tokenizer

# %%
# 정수 인코딩(Integer Encoding)
# ❖ 각 단어를 고유한 정수에 맵핑(mapping)시키는 전처리 작업이 필요
# ex) book-150, dog-71, love-192, books-212
# >>> from tensorflow.keras.preprocessing.text import Tokenizer
# >>> sentences=[['barber', 'person'], ['barber', 'good', 'person'], ['barber', 'huge',
# 'person'], ['knew', 'secret'], ['secret', 'kept', 'huge', 'secret'], ['huge', 'secret'], ['barber',
# 'kept', 'word'], ['barber', 'kept', 'word'], ['barber', 'kept', 'secret'], ['keeping', 'keeping',
# 'huge', 'secret', 'driving', 'barber', 'crazy'], ['barber', 'went', 'huge', 'mountain']]
# >>> tokenizer = Tokenizer(num_words = 6, oov_token = 'OOV') # 빈도 순위 5까지
# >>> tokenizer.fit_on_texts(sentences)
# >>> print(tokenizer.word_index)
# {'OOV': 1, 'barber': 2, 'secret': 3, 'huge': 4, 'kept': 5, 'person': 6, 'word': 7, 'keeping': 8,
# 'good': 9, 'knew': 10, 'driving': 11, 'crazy': 12, 'went': 13, 'mountain': 14}
# >>> print(tokenizer.word_counts)
# OrderedDict([('barber', 8), ('person', 3), ('good', 1), ('huge', 5), ('knew', 1), ('secret',
# 6), ('kept', 4), ('word', 2), ('keeping', 2), ('driving', 1), ('crazy', 1), ('went', 1), ...])
# >>> print(tokenizer.texts_to_sequences(sentences)) # num_words 적용됨
# [[2, 1], [2, 1, 1], [2, 4, 1], [1, 3], [3, 5, 4, 3], [4, 3], [2, 5, 1], [2, 5, 1], [2, 5, 3], ...]
# ❖ 해 보기
# ➢ 한글 문장(최소 3개)을 위와 같이 sentences를 만들기(정규화와 for문 사용)
# ➢ Tokenizer 적용하기

# %% [markdown]
# # ➢ Naver Movie review 적용해 보기
# ## (정규화 Function 작성 권장)

# %%
train_url = 'https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt'
test_url = 'https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt'

import pandas as pd
train = pd.read_csv(train_url, sep="\t")
test = pd.read_csv(test_url, sep="\t")

# %%
train.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
x_train = train['document']
y_train = train['label']
x_test = test['document']
y_test = test['label']

# %%
type(x_train)
# 겉은 판다스
# Out:
# pandas.core.series.Series

# %%
type(x_train[0])
# 속은 str
# Out:
# str

# %%
x_train = x_train.values.tolist()
# 겉을 list로 변환

# %%
import numpy as np
x_train = np.array(x_train)
x_train
# numpy로 변환
# Out:
# array(['아 더빙.. 진짜 짜증나네요 목소리', '흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나',
#        '너무재밓었다그래서보는것을추천한다', ..., '이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?',
#        '청춘 영화의 최고봉.방황과 우울했던 날들의 자화상', '한국 영화 최초로 수간하는 내용이 담긴 영화'],
#       dtype='<U146')

# %%
# tokenizer = Tokenizer(lower=False)
# tokenizer.fit_on_texts([str(x)])

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(x_train) # 이미 list 형태이기 때문에 또 하지 않는다.
tokenizer.word_index  # 사전 vocabulary 만들기

# 한 사이클 다 돌아가고 난 뒤에, 사전 만들기 전에 (vocabulary), cleaning
# Out:
# {'영화': 1,
#  '너무': 2,
#  '정말': 3,
#  '진짜': 4,
#  '이': 5,
#  '그냥': 6,
#  '왜': 7,
#  '이런': 8,
#  '더': 9,
#  '수': 10,
#  '영화를': 11,
#  '다': 12,
#  '잘': 13,
#  '좀': 14,
#  '보고': 15,
#  'ㅋㅋ': 16,
#  '그': 17,
#  '영화는': 18,
#  '영화가': 19,
#  '본': 20,
#  '봤는데': 21,
#  '최고의': 22,
#  '아': 23,
#  '이건': 24,
#  '내가': 25,
#  '없는': 26,
#  '없다': 27,
#  '드라마': 28,
#  '완전': 29,
#  '이렇게': 30,
#  '참': 31,
#  '이거': 32,
#  '평점': 33,
#  '그리고': 34,
#  '이게': 35,
#  '좋은': 36,
#  '있는': 37,
#  '연기': 38,
#  '내': 39,
#  '평점이': 40,
#  '보는': 41,
#  '다시': 42,
#  '스토리': 43,
#  '역시': 44,
#  '최고': 45,
#  '쓰레기': 46,
#  '난': 47,
#  '많이': 48,
#  'ㅋ': 49,
#  '것': 50,
#  'ㅋㅋㅋ': 51,
#  '한': 52,
#  'ㅠㅠ': 53,
#  '재밌게': 54,
#  '없고': 55,
#  '또': 56,
#  '하는': 57,
#  '아깝다': 58,
#  '꼭': 59,
#  '보면': 60,
#  '가장': 61,
#  '마지막': 62,
#  '뭐': 63,
#  '영화다': 64,
#  '무슨': 65,
#  '하지만': 66,
#  'ㅡㅡ': 67,
#  'ㅎㅎ': 68,
#  '10점': 69,
#  '별로': 70,
#  '같은': 71,
#  '작품': 72,
#  '솔직히': 73,
#  '끝까지': 74,
#  '볼': 75,
#  '넘': 76,
#  '안': 77,
#  '대한': 78,
#  '만든': 79,
#  '와': 80,
#  '봐도': 81,
#  'ㅠ': 82,
#  '전혀': 83,
#  '그래도': 84,
#  '같다': 85,
#  '말이': 86,
#  '좋다': 87,
#  '지금': 88,
#  '아주': 89,
#  '뭔가': 90,
#  '있다': 91,
#  '영화의': 92,
#  '하고': 93,
#  '내내': 94,
#  '근데': 95,
#  '재미': 96,
#  '최악의': 97,
#  '다른': 98,
#  '굿': 99,
#  '할': 100,
#  '않고': 101,
#  '어떻게': 102,
#  '감독': 103,
#  '감동': 104,
#  '하나': 105,
#  '봤다': 106,
#  '연기가': 107,
#  '많은': 108,
#  '재밌다': 109,
#  '재미있게': 110,
#  '별': 111,
#  '이걸': 112,
#  '듯': 113,
#  '아니다': 114,
#  '중': 115,
#  '재미없다': 116,
#  '명작': 117,
#  '이야기': 118,
#  '연기도': 119,
#  '아니라': 120,
#  '보다가': 121,
#  '스토리가': 122,
#  '1점': 123,
#  '느낌': 124,
#  '아름다운': 125,
#  '차라리': 126,
#  '특히': 127,
#  '모두': 128,
#  '시간': 129,
#  '내용도': 130,
#  '나는': 131,
#  '액션': 132,
#  '계속': 133,
#  '제대로': 134,
#  '때문에': 135,
#  '내용이': 136,
#  '아니고': 137,
#  '나오는': 138,
#  '모든': 139,
#  '영화에': 140,
#  '연출': 141,
#  '제일': 142,
#  '감독이': 143,
#  '않은': 144,
#  '아직도': 145,
#  '스토리도': 146,
#  '때': 147,
#  '아닌': 148,
#  '도대체': 149,
#  '보다': 150,
#  '영화라고': 151,
#  '감독의': 152,
#  '시간이': 153,
#  '배우들': 154,
#  '영화입니다': 155,
#  '재미도': 156,
#  '여운이': 157,
#  '싶다': 158,
#  '마지막에': 159,
#  'ㅡ': 160,
#  '딱': 161,
#  '보면서': 162,
#  '나도': 163,
#  '오랜만에': 164,
#  '않는': 165,
#  '만드는': 166,
#  '한번': 167,
#  'ㅎ': 168,
#  '재밌어요': 169,
#  '걍': 170,
#  '좋았다': 171,
#  'ㅋㅋㅋㅋ': 172,
#  '진심': 173,
#  '나름': 174,
#  '아까운': 175,
#  '지루하고': 176,
#  '처음': 177,
#  '짱': 178,
#  '배우들의': 179,
#  '봤습니다': 180,
#  '좋고': 181,
#  '내용': 182,
#  '이제': 183,
#  '최고다': 184,
#  '이영화': 185,
#  '없음': 186,
#  '없이': 187,
#  '그런': 188,
#  '요즘': 189,
#  '절대': 190,
#  '보는내내': 191,
#  '개인적으로': 192,
#  '최악': 193,
#  '1점도': 194,
#  '좋아하는': 195,
#  '줄': 196,
#  '대박': 197,
#  '남는': 198,
#  '1': 199,
#  '조금': 200,
#  '보기': 201,
#  '주는': 202,
#  '보세요': 203,
#  '이해가': 204,
#  '못': 205,
#  '연기는': 206,
#  '얼마나': 207,
#  '아무리': 208,
#  '뻔한': 209,
#  'ㅜㅜ': 210,
#  '그저': 211,
#  '영화로': 212,
#  '전': 213,
#  '영화도': 214,
#  '너무나': 215,
#  '재미가': 216,
#  '제발': 217,
#  '기억에': 218,
#  '생각이': 219,
#  '엄청': 220,
#  '멋진': 221,
#  '봤던': 222,
#  '한국': 223,
#  '되는': 224,
#  '주인공': 225,
#  '배우': 226,
#  '강추': 227,
#  '괜찮은': 228,
#  '극장에서': 229,
#  '있고': 230,
#  '결국': 231,
#  '지루하다': 232,
#  '그래서': 233,
#  '그렇게': 234,
#  '매우': 235,
#  '게': 236,
#  '사람이': 237,
#  '내용은': 238,
#  '돈': 239,
#  '나': 240,
#  '좋아요': 241,
#  '위해': 242,
#  '두': 243,
#  '하나도': 244,
#  '그나마': 245,
#  '봤어요': 246,
#  '인생': 247,
#  '모르겠다': 248,
#  '싶은': 249,
#  '것이': 250,
#  '영화네요': 251,
#  '함께': 252,
#  '건': 253,
#  '가슴이': 254,
#  '개': 255,
#  '안되는': 256,
#  '위한': 257,
#  '한다': 258,
#  '마음이': 259,
#  '코미디': 260,
#  '지루한': 261,
#  '않는다': 262,
#  '갈수록': 263,
#  '뭘': 264,
#  '같이': 265,
#  '아니': 266,
#  '못한': 267,
#  '사랑': 268,
#  '재미없음': 269,
#  '된': 270,
#  '연기를': 271,
#  '재밌는': 272,
#  '눈물이': 273,
#  '재밌음': 274,
#  '어떤': 275,
#  '것도': 276,
#  '간만에': 277,
#  '큰': 278,
#  '2': 279,
#  '밖에': 280,
#  '재밌고': 281,
#  '대체': 282,
#  '것을': 283,
#  '사람': 284,
#  '꽤': 285,
#  '훨씬': 286,
#  '다들': 287,
#  '거': 288,
#  '아쉽다': 289,
#  'good': 290,
#  '나온': 291,
#  '저': 292,
#  '장면': 293,
#  '기억이': 294,
#  '영화중': 295,
#  '결말이': 296,
#  '누가': 297,
#  '보지': 298,
#  '스릴러': 299,
#  '감동도': 300,
#  '영화관에서': 301,
#  '어설픈': 302,
#  '스토리는': 303,
#  '진정한': 304,
#  '전개': 305,
#  '했는데': 306,
#  '아님': 307,
#  '없었다': 308,
#  '추천': 309,
#  '좋은데': 310,
#  '우리': 311,
#  '생각을': 312,
#  '사람들이': 313,
#  '상당히': 314,
#  '배우들이': 315,
#  '않다': 316,
#  '영화였다': 317,
#  '오늘': 318,
#  '뭔': 319,
#  '대해': 320,
#  '정도': 321,
#  '잔잔한': 322,
#  '생각보다': 323,
#  '정도로': 324,
#  '걸': 325,
#  '일본': 326,
#  '그러나': 327,
#  '여자': 328,
#  '지루함': 329,
#  '수작': 330,
#  '감동을': 331,
#  '중간에': 332,
#  '졸작': 333,
#  '같은데': 334,
#  '감동적인': 335,
#  '같아요': 336,
#  '바로': 337,
#  '음': 338,
#  '결말': 339,
#  '느낌이': 340,
#  '뭐지': 341,
#  '반전': 342,
#  '연기력': 343,
#  '재미있어요': 344,
#  '보여주는': 345,
#  '보니': 346,
#  '우리나라': 347,
#  '하': 348,
#  '있지만': 349,
#  '주고': 350,
#  '있을까': 351,
#  '수준': 352,
#  '봤지만': 353,
#  '보게': 354,
#  '원작을': 355,
#  '재미는': 356,
#  '나와서': 357,
#  '준다': 358,
#  '해서': 359,
#  '굉장히': 360,
#  '거의': 361,
#  '음악': 362,
#  'ㅉㅉ': 363,
#  '갑자기': 364,
#  '재미있다': 365,
#  '재밌네요': 366,
#  '나의': 367,
#  '뭐야': 368,
#  '장면이': 369,
#  '말': 370,
#  '평점을': 371,
#  '기대': 372,
#  '될': 373,
#  '영화인데': 374,
#  '당시': 375,
#  '존나': 376,
#  '사람들': 377,
#  '자체가': 378,
#  '마음에': 379,
#  '이영화를': 380,
#  '약간': 381,
#  '쓰레기영화': 382,
#  '저는': 383,
#  '제가': 384,
#  'ㅜ': 385,
#  '알고': 386,
#  '봐라': 387,
#  '영화임': 388,
#  '하다': 389,
#  '훌륭한': 390,
#  '충분히': 391,
#  '일단': 392,
#  '있어서': 393,
#  '한마디로': 394,
#  '재미있는': 395,
#  '사람은': 396,
#  '항상': 397,
#  '그대로': 398,
#  '그런지': 399,
#  '하지': 400,
#  '감독은': 401,
#  '긴장감': 402,
#  '것은': 403,
#  '막장': 404,
#  '비해': 405,
#  '시리즈': 406,
#  '어디서': 407,
#  '말도': 408,
#  '아까움': 409,
#  '뭐냐': 410,
#  '봐서': 411,
#  '없어서': 412,
#  '처음부터': 413,
#  '주인공이': 414,
#  '기분': 415,
#  '노잼': 416,
#  '새로운': 417,
#  '있는데': 418,
#  '볼만한': 419,
#  '후': 420,
#  '준': 421,
#  '가지고': 422,
#  '몰입도': 423,
#  '좋네요': 424,
#  '이영화는': 425,
#  'b급': 426,
#  '합니다': 427,
#  '맘에': 428,
#  '평점은': 429,
#  '아직': 430,
#  '수가': 431,
#  '♥': 432,
#  '전개가': 433,
#  '점점': 434,
#  '했다': 435,
#  '이딴': 436,
#  '도저히': 437,
#  '다시봐도': 438,
#  '봤음': 439,
#  '뭐가': 440,
#  '그게': 441,
#  '오히려': 442,
#  '가슴': 443,
#  'oo': 444,
#  '사람들은': 445,
#  '생각': 446,
#  '재밌는데': 447,
#  '더욱': 448,
#  '대사': 449,
#  '물론': 450,
#  '무조건': 451,
#  '감동이': 452,
#  '애니메이션': 453,
#  '이것도': 454,
#  '사랑을': 455,
#  '캐릭터': 456,
#  'ㅎㅎㅎ': 457,
#  '보는데': 458,
#  '재미없는': 459,
#  '뿐': 460,
#  '생각하게': 461,
#  '전부': 462,
#  '없어': 463,
#  '엄청난': 464,
#  '전형적인': 465,
#  '시나리오': 466,
#  '대단한': 467,
#  '그만': 468,
#  '실망': 469,
#  '모르고': 470,
#  '제': 471,
#  '평점에': 472,
#  '해도': 473,
#  '라는': 474,
#  '좋겠다': 475,
#  '예전에': 476,
#  '3': 477,
#  '액션도': 478,
#  '없네': 479,
#  '입니다': 480,
#  '이야기를': 481,
#  '인간의': 482,
#  '따뜻한': 483,
#  '애니': 484,
#  '배우가': 485,
#  '원래': 486,
#  '지금도': 487,
#  '완벽한': 488,
#  '걸작': 489,
#  '헐': 490,
#  '봤네요': 491,
#  '재밌었다': 492,
#  '그닥': 493,
#  '4': 494,
#  '듯한': 495,
#  '만들어': 496,
#  '3류': 497,
#  '억지로': 498,
#  '남자': 499,
#  '것이다': 500,
#  '별점': 501,
#  '너무너무': 502,
#  '없네요': 503,
#  '영': 504,
#  '공포': 505,
#  '좋았어요': 506,
#  '하면': 507,
#  '네이버': 508,
#  '봄': 509,
#  '저도': 510,
#  '아무것도': 511,
#  '말고': 512,
#  '더럽게': 513,
#  '된다': 514,
#  '처음으로': 515,
#  '원작': 516,
#  '가': 517,
#  '자꾸': 518,
#  '우연히': 519,
#  '억지': 520,
#  '특유의': 521,
#  '그런데': 522,
#  '낫다': 523,
#  '이미': 524,
#  '좋음': 525,
#  '재미있고': 526,
#  '안된다': 527,
#  '좋아': 528,
#  '돈이': 529,
#  '아닌가': 530,
#  '있음': 531,
#  '그의': 532,
#  '몇': 533,
#  '돈주고': 534,
#  '장면은': 535,
#  '공포영화': 536,
#  '유치하고': 537,
#  '알았는데': 538,
#  '또한': 539,
#  '못하는': 540,
#  '재미없고': 541,
#  '빨리': 542,
#  '한국영화': 543,
#  '명작이다': 544,
#  '이런걸': 545,
#  '눈물': 546,
#  '마치': 547,
#  '화이팅': 548,
#  '유치한': 549,
#  '알았다': 550,
#  '영화라': 551,
#  '영화보다': 552,
#  '느낄': 553,
#  '최악이다': 554,
#  '사실': 555,
#  '중에': 556,
#  '있었다': 557,
#  '알': 558,
#  '믿고': 559,
#  '저런': 560,
#  '연출이': 561,
#  '아이들이': 562,
#  '마음을': 563,
#  '미친': 564,
#  '영화에서': 565,
#  '영상': 566,
#  '스토리에': 567,
#  '너무나도': 568,
#  '왜이리': 569,
#  '아니지만': 570,
#  '이상': 571,
#  '잘봤습니다': 572,
#  '0': 573,
#  '모습이': 574,
#  '그렇고': 575,
#  '애들': 576,
#  '소재는': 577,
#  '어느': 578,
#  '하게': 579,
#  '뭔지': 580,
#  '아니면': 581,
#  '이젠': 582,
#  '드라마를': 583,
#  '지금봐도': 584,
#  '로맨스': 585,
#  '지금까지': 586,
#  '괜히': 587,
#  '않음': 588,
#  '별로다': 589,
#  '다만': 590,
#  'ooo': 591,
#  '막': 592,
#  '하는데': 593,
#  '어릴때': 594,
#  '같습니다': 595,
#  '이해': 596,
#  '기대하고': 597,
#  '삶을': 598,
#  '왠지': 599,
#  '진부한': 600,
#  '이야기가': 601,
#  '흠': 602,
#  '못하고': 603,
#  '감사합니다': 604,
#  '이런게': 605,
#  '영화였습니다': 606,
#  '앞으로': 607,
#  '감독님': 608,
#  '드라마가': 609,
#  '확실히': 610,
#  '전체적으로': 611,
#  '좋았습니다': 612,
#  '좋았고': 613,
#  '웃음': 614,
#  '느끼게': 615,
#  '화려한': 616,
#  '무엇보다': 617,
#  '재밌었어요': 618,
#  '만들지': 619,
#  '의': 620,
#  '다소': 621,
#  '여자가': 622,
#  '역시나': 623,
#  '자신의': 624,
#  '아놔': 625,
#  '소재': 626,
#  '영화이다': 627,
#  '모습을': 628,
#  '이영화가': 629,
#  '혼자': 630,
#  '좋았는데': 631,
#  '영화중에': 632,
#  '했지만': 633,
#  '스토리와': 634,
#  '대단하다': 635,
#  '액션은': 636,
#  '끝': 637,
#  '영화지만': 638,
#  '굳': 639,
#  '발연기': 640,
#  '재미없어': 641,
#  '있어': 642,
#  '보지마세요': 643,
#  '날': 644,
#  '나를': 645,
#  '여전히': 646,
#  '이런영화': 647,
#  '같네요': 648,
#  '여주인공': 649,
#  '않았다': 650,
#  '가는': 651,
#  '눈이': 652,
#  '비슷한': 653,
#  '내용을': 654,
#  '볼때마다': 655,
#  '본다': 656,
#  '좋았음': 657,
#  '생각한다': 658,
#  '어렸을때': 659,
#  '허접한': 660,
#  '있다는': 661,
#  '아쉬운': 662,
#  'tv': 663,
#  'ㅅㅂ': 664,
#  '모르는': 665,
#  '부분이': 666,
#  '연기에': 667,
#  '캐스팅': 668,
#  '그런가': 669,
#  '점수': 670,
#  '있다면': 671,
#  '5': 672,
#  '드라마는': 673,
#  '매력적인': 674,
#  '소재를': 675,
#  '스토리를': 676,
#  '보고나서': 677,
#  '아닐까': 678,
#  '반전이': 679,
#  '봐야': 680,
#  '이런거': 681,
#  '든다': 682,
#  '순수한': 683,
#  '함': 684,
#  '8': 685,
#  '사람을': 686,
#  '처음이다': 687,
#  '유쾌한': 688,
#  '왜이렇게': 689,
#  '추천합니다': 690,
#  'ㄷㄷ': 691,
#  '세상에': 692,
#  '높은': 693,
#  '나만': 694,
#  '보는게': 695,
#  'ㅋㅋㅋㅋㅋ': 696,
#  '그들의': 697,
#  '슬픈': 698,
#  '지난': 699,
#  '아무': 700,
#  '깊은': 701,
#  '7': 702,
#  '부족한': 703,
#  '과연': 704,
#  '전에': 705,
#  '보기엔': 706,
#  '이리': 707,
#  '연기와': 708,
#  '봤었는데': 709,
#  '어이없는': 710,
#  '굳이': 711,
#  '옛날': 712,
#  '있을': 713,
#  '액션이': 714,
#  '주인공의': 715,
#  '이유가': 716,
#  '난다': 717,
#  '귀엽고': 718,
#  '나오고': 719,
#  '통해': 720,
#  '노래': 721,
#  '영화보고': 722,
#  '삼류': 723,
#  '눈을': 724,
#  '감동적이고': 725,
#  '연기력이': 726,
#  '꿀잼': 727,
#  '개연성': 728,
#  '재미있음': 729,
#  '아름답고': 730,
#  '이정도면': 731,
#  '언제': 732,
#  '등': 733,
#  '음악이': 734,
#  '아닌데': 735,
#  '에휴': 736,
#  '정말로': 737,
#  '슬프다': 738,
#  '재밌었는데': 739,
#  '현실을': 740,
#  '먼저': 741,
#  '아름답다': 742,
#  '졸라': 743,
#  '안되고': 744,
#  '안하고': 745,
#  '전기세가': 746,
#  '2점': 747,
#  '마라': 748,
#  '독특한': 749,
#  '매력이': 750,
#  '오': 751,
#  '안됨': 752,
#  '어색한': 753,
#  '기대를': 754,
#  '봤다가': 755,
#  '있었던': 756,
#  '남는다': 757,
#  '힘든': 758,
#  '느껴지는': 759,
#  '보여준': 760,
#  '음악도': 761,
#  '나온다': 762,
#  '재미를': 763,
#  '마음': 764,
#  '생각합니다': 765,
#  '보시길': 766,
#  '평범한': 767,
#  '해준': 768,
#  '재밌습니다': 769,
#  '진심으로': 770,
#  '그럭저럭': 771,
#  '같음': 772,
#  'the': 773,
#  '좋은영화': 774,
#  '이유는': 775,
#  '참고': 776,
#  '영화냐': 777,
#  '그다지': 778,
#  '지루해서': 779,
#  '하면서': 780,
#  '처음엔': 781,
#  '배우의': 782,
#  '90년대': 783,
#  '저렇게': 784,
#  '연출도': 785,
#  '감동과': 786,
#  '80년대': 787,
#  '역대': 788,
#  '사람의': 789,
#  '판타지': 790,
#  '중간중간': 791,
#  '보이는': 792,
#  '볼수': 793,
#  '사랑에': 794,
#  '티비에서': 795,
#  '귀여운': 796,
#  '우리가': 797,
#  '이상한': 798,
#  '질질': 799,
#  '9점': 800,
#  '살짝': 801,
#  '볼수록': 802,
#  '구성': 803,
#  '그럼': 804,
#  '사랑이': 805,
#  '공감이': 806,
#  '재미없네': 807,
#  '삶의': 808,
#  '나왔으면': 809,
#  '10': 810,
#  '라고': 811,
#  '필요없다': 812,
#  '휴': 813,
#  '신선한': 814,
#  '볼만함': 815,
#  '소재가': 816,
#  '지루해': 817,
#  '하네요': 818,
#  '없지만': 819,
#  '봤으면': 820,
#  '몰라도': 821,
#  '나에게': 822,
#  '좋습니다': 823,
#  '되었다': 824,
#  '게다가': 825,
#  '대충': 826,
#  '몰입이': 827,
#  '나중에': 828,
#  '여기': 829,
#  '지루하지': 830,
#  '9': 831,
#  '배우들도': 832,
#  '필요없는': 833,
#  '이건뭐': 834,
#  '해주는': 835,
#  '지루': 836,
#  '추억의': 837,
#  '제목이': 838,
#  '딱히': 839,
#  '알게': 840,
#  '사랑하는': 841,
#  '좋아서': 842,
#  '아닌듯': 843,
#  '언제나': 844,
#  '결말은': 845,
#  '속': 846,
#  '그리': 847,
#  '아오': 848,
#  '제목': 849,
#  '반전도': 850,
#  '지금은': 851,
#  '했던': 852,
#  'ost': 853,
#  '만들어진': 854,
#  '드는': 855,
#  '끝나고': 856,
#  '여주': 857,
#  '미국': 858,
#  '엔딩': 859,
#  '번': 860,
#  '떨어지는': 861,
#  '마세요': 862,
#  '애들이': 863,
#  '인생을': 864,
#  '가서': 865,
#  '시간을': 866,
#  '단': 867,
#  'ㅠㅠㅠ': 868,
#  '더이상': 869,
#  '점수를': 870,
#  '자기': 871,
#  '만들': 872,
#  '이후': 873,
#  '기분이': 874,
#  '작가': 875,
#  '밑에': 876,
#  '어린': 877,
#  '쓴': 878,
#  '가볍게': 879,
#  '필요': 880,
#  '비추': 881,
#  '단지': 882,
#  '글쎄': 883,
#  '3점': 884,
#  '서로': 885,
#  '0점': 886,
#  '않게': 887,
#  '대한민국': 888,
#  '있지': 889,
#  '그래': 890,
#  '재미있네요': 891,
#  '각본': 892,
#  '않을': 893,
#  '있습니다': 894,
#  '슬프고': 895,
#  '를': 896,
#  '와우': 897,
#  '싫다': 898,
#  '불구하고': 899,
#  '웃기고': 900,
#  '아까워': 901,
#  '매력': 902,
#  '건지': 903,
#  '짜증나는': 904,
#  '쉽게': 905,
#  '봐야할': 906,
#  '크게': 907,
#  '짜증': 908,
#  '암튼': 909,
#  '가진': 910,
#  '까지': 911,
#  '시대를': 912,
#  '만큼': 913,
#  '보고싶다': 914,
#  '현실': 915,
#  '킬링타임용': 916,
#  '멋지다': 917,
#  '사랑과': 918,
#  '낮아서': 919,
#  '눈물을': 920,
#  '부터': 921,
#  '쩝': 922,
#  '분위기': 923,
#  '결말도': 924,
#  '어이가': 925,
#  '엉성한': 926,
#  '이제야': 927,
#  '있나': 928,
#  '수도': 929,
#  '설정': 930,
#  '만': 931,
#  '겁나': 932,
#  '열심히': 933,
#  '좀더': 934,
#  '만들고': 935,
#  '더빙': 936,
#  '지': 937,
#  '죄다': 938,
#  '프랑스': 939,
#  '되게': 940,
#  '내인생': 941,
#  '보니까': 942,
#  '소재로': 943,
#  '0점은': 944,
#  '실제': 945,
#  '느낌을': 946,
#  '있게': 947,
#  '한데': 948,
#  '단순한': 949,
#  '봣는데': 950,
#  '만들었다': 951,
#  '잔잔하고': 952,
#  '무엇을': 953,
#  '그렇다고': 954,
#  '같아': 955,
#  '모든게': 956,
#  '작품이': 957,
#  '둘다': 958,
#  '알바': 959,
#  '잘만든': 960,
#  '있어요': 961,
#  '되지': 962,
#  '뻔하고': 963,
#  '말을': 964,
#  'ooo기': 965,
#  '못했다': 966,
#  '처럼': 967,
#  '뛰어난': 968,
#  '없을': 969,
#  '모습': 970,
#  '재밌었음': 971,
#  '사랑스러운': 972,
#  '이런영화가': 973,
#  '망작': 974,
#  '맞는': 975,
#  '같아서': 976,
#  '남자가': 977,
#  '잼있게': 978,
#  '몇번을': 979,
#  '아는': 980,
#  '않지만': 981,
#  '안타깝다': 982,
#  '재미있었다': 983,
#  '사는': 984,
#  '재미없어요': 985,
#  '생애': 986,
#  '만화': 987,
#  '시절': 988,
#  '작가가': 989,
#  '나옴': 990,
#  '평생': 991,
#  '누구나': 992,
#  '떠나서': 993,
#  '극장판': 994,
#  '그걸': 995,
#  '가끔': 996,
#  '여배우': 997,
#  '옛날에': 998,
#  '4점': 999,
#  '가족': 1000,
#  ...}

# %%
len(tokenizer.word_index)
# Out:
# 296311

# %%
x_train = tokenizer.texts_to_sequences(x_train)
# 서로 사이즈 맞추기 위함

# 단어를 사전을 이용하여 숫자로 변환
# 2차원 형태

# %%
x_train
# 숫자로 변환된 x_train을 모델링 해줘야 함
# 지금상태에서 x_train은 그냥 문자형태임
# 위에 숫자로 변환된거 변수로 저장해야 함
# Out:
# [[23, 936, 4, 6727, 1097],
#  [602, 6117, 72133, 72134, 7052, 31482],
#  [72135],
#  [24946, 72136, 73, 356, 27, 33, 10431],
#  [72137, 43157, 107, 5354, 1, 72138, 72139, 852, 24947, 72140, 568, 72141],
#  [592, 72142, 43158, 72143, 2290, 72144, 72145, 51, 4218, 409],
#  [1098, 2234, 134, 72146],
#  [111,
#   1254,
#   58,
#   2741,
#   31483,
#   72147,
#   72148,
#   3,
#   72149,
#   24948,
#   43159,
#   8961,
#   72150,
#   8962,
#   72151,
#   72152],
#  [714, 20666, 96, 37, 4915, 1],
#  [1187, 40, 72153, 285, 3285, 9614, 72154, 2, 31484, 928],
#  [72155, 72156],
#  [655, 43160, 72157, 72158, 72159, 72160, 31485],
#  [2235, 72161, 72162, 72163, 72164, 6118, 38, 72165],
#  [9615, 20667, 87, 72166, 150, 60, 518, 72167, 11355, 72168, 283],
#  [3647, 72169, 4, 1974, 229, 20, 295, 61, 416, 72170, 146, 43161, 300, 5127],
#  [72171, 2327, 13820, 72172],
#  [31,
#   377,
#   9616,
#   43162,
#   20668,
#   72173,
#   72174,
#   20668,
#   72175,
#   43163,
#   6,
#   72176,
#   72177,
#   1111],
#  [7875, 43164, 72178, 17715, 7, 1361, 263, 72179],
#  [24, 3, 15410, 9617, 72180, 17716, 43165, 13, 43166, 72181, 432],
#  [72182, 257, 15411, 7876, 72183, 72184, 190, 72185],
#  [174, 4082, 15412, 37, 113, 6, 17717, 31486, 12468, 18, 190, 307],
#  [162, 8963, 165, 253, 15413],
#  [116,
#   176,
#   71,
#   6383,
#   4083,
#   43167,
#   72186,
#   76,
#   72187,
#   43167,
#   72188,
#   3744,
#   230,
#   6383,
#   31487,
#   418,
#   24,
#   10432,
#   72189,
#   70,
#   3286,
#   24949,
#   72190,
#   72191,
#   1283,
#   70,
#   2939,
#   67],
#  [190, 767, 19, 148, 72192, 43168],
#  [3068, 310, 3186, 232],
#  [12, 72193, 233, 24950, 10, 72194, 72195, 59, 72196],
#  [72197, 72198, 72199, 7053],
#  [43169, 640],
#  [72200],
#  [12469, 1034, 3003, 668, 11356, 15414, 233, 800],
#  [72201, 24951, 42, 167, 1476, 768, 2564, 1885, 72202, 38, 3, 506, 29, 13821],
#  [72203, 72204, 23, 3964],
#  [447, 2615, 569, 72205],
#  [199, 17718, 3965, 25, 43170, 43170],
#  [145, 5, 673, 7877, 45],
#  [43171, 78, 5587, 5588, 72206],
#  [11357, 43172, 72207, 31488, 282, 72208, 72209],
#  [2565, 31489, 4551, 72210, 43173],
#  [4219, 72211, 5828, 72212],
#  [5, 19, 7, 30, 5829, 20669, 248],
#  [43174, 6119, 7464, 1],
#  [43175,
#   20670,
#   130,
#   55,
#   72213,
#   55,
#   72214,
#   244,
#   186,
#   29,
#   72215,
#   1,
#   1362,
#   72216,
#   76,
#   409,
#   29,
#   5830],
#  [72217, 72218, 72219],
#  [3, 428, 6384, 233, 56, 2566, 56, 41, 4552, 479, 12470],
#  [72220,
#   221,
#   1307,
#   15415,
#   7054,
#   1627,
#   31490,
#   322,
#   4084,
#   31491,
#   427,
#   2236,
#   200,
#   31492,
#   1179,
#   350,
#   1211,
#   33,
#   8964,
#   2357,
#   69,
#   43176],
#  [72221, 43177],
#  [8389,
#   72222,
#   948,
#   278,
#   5128,
#   1768,
#   72223,
#   72224,
#   43178,
#   8965,
#   72225,
#   9618,
#   43179,
#   5129,
#   24952,
#   72226,
#   200,
#   43180,
#   4743,
#   2472,
#   13822,
#   2053,
#   263,
#   7878,
#   24953,
#   43181],
#  [5355,
#   43182,
#   49,
#   17719,
#   15,
#   15416,
#   161,
#   72227,
#   363,
#   17720,
#   681,
#   13823,
#   239,
#   72228],
#  [47, 72229, 1975],
#  [72230,
#   43183,
#   72231,
#   163,
#   72232,
#   1001,
#   158,
#   72233,
#   72234,
#   93,
#   72235,
#   2204,
#   43184,
#   142,
#   221,
#   5130,
#   72236,
#   72237,
#   72238,
#   11358,
#   7879,
#   5,
#   142,
#   11359,
#   614,
#   608,
#   10433,
#   279,
#   7880,
#   72239,
#   10434,
#   72240,
#   3004,
#   72241,
#   1828],
#  [19,
#   789,
#   4220,
#   43185,
#   196,
#   929,
#   8390,
#   6385,
#   72242,
#   2669,
#   2205,
#   2742,
#   140,
#   72243],
#  [1547, 17721, 43186, 24954, 24955, 72244, 20671, 1284],
#  [30, 72245, 20, 609, 56, 351, 104, 17, 1131],
#  [17722, 292, 31493, 65, 43187, 72246, 2291, 444, 6, 630, 72247, 72248, 4085],
#  [344],
#  [213, 241],
#  [45],
#  [2,
#   72249,
#   7465,
#   1118,
#   1342,
#   43188,
#   57,
#   124,
#   72250,
#   244,
#   26,
#   568,
#   2510,
#   20672,
#   15417,
#   72251,
#   211,
#   31494,
#   8391,
#   3,
#   31495,
#   5131,
#   219,
#   682],
#  [24956],
#  [72252, 43189],
#  [191, 398, 17723, 7881, 2616, 26, 3124],
#  [72253, 357, 12471, 1797, 19, 332, 1225, 124],
#  [31496, 17724, 767, 4383, 200, 43190, 602],
#  [72254,
#   72255,
#   1165,
#   3840,
#   6386,
#   72256,
#   72257,
#   5589,
#   72258,
#   2054,
#   210,
#   1119,
#   20673,
#   72259,
#   72260,
#   20674,
#   210],
#  [72261, 72262],
#  [108,
#   313,
#   5,
#   3447,
#   15,
#   347,
#   698,
#   31497,
#   52,
#   31498,
#   320,
#   1406,
#   1055,
#   72263,
#   337,
#   31499,
#   242,
#   72264,
#   427,
#   13824,
#   13825,
#   72265,
#   17,
#   17725,
#   43191,
#   1075,
#   1628,
#   2411,
#   24,
#   7882,
#   72266,
#   72267,
#   12,
#   72268],
#  [1678,
#   72,
#   456,
#   3187,
#   8392,
#   20675,
#   72269,
#   43192,
#   238,
#   1132,
#   1886,
#   6728,
#   72270,
#   183,
#   72271,
#   72272],
#  [24957, 72273, 3005, 1019, 72274, 899, 176, 6387, 72275],
#  [1076, 653, 11, 12472, 72276, 4744, 113],
#  [72277, 9619, 43193, 72278, 4, 24958],
#  [23, 1461, 72279, 1154],
#  [17726,
#   12,
#   246,
#   169,
#   95,
#   4384,
#   1629,
#   24952,
#   7055,
#   72280,
#   507,
#   4384,
#   43194,
#   72281,
#   3448,
#   43194,
#   15418,
#   72282,
#   2670,
#   72283,
#   72284,
#   72285,
#   43195,
#   77,
#   72286,
#   51,
#   188,
#   253,
#   43196,
#   84,
#   182,
#   1497,
#   506],
#  [333],
#  [3365, 31500, 10435, 9, 618],
#  [302, 305, 710, 339],
#  [17727, 72287, 72288, 24959, 17728, 1, 20676, 72289, 3648, 72290, 211, 72291],
#  [31501, 6120, 72292, 13, 1343],
#  [235, 469],
#  [543,
#   72293,
#   3966,
#   3966,
#   43197,
#   72294,
#   3966,
#   17729,
#   104,
#   33,
#   69,
#   12473,
#   3006,
#   7466,
#   63],
#  [31502, 31502, 31502],
#  [410, 7883, 17730, 1916, 72295, 5590, 1160, 72296],
#  [1180, 2412, 20677],
#  [143, 72297, 11, 31503, 3449, 264, 31504, 1035, 5591, 72298],
#  [24, 410, 72299],
#  [72300],
#  [1212, 1099, 1, 1308],
#  [1120, 3366],
#  [10436, 3745],
#  [95, 72301, 72302, 72303],
#  [51, 4, 72304, 16, 1145, 72305, 72306, 16],
#  [12474, 11360, 16],
#  [72307, 43198, 72308, 13, 15419],
#  [72309],
#  [29, 72310],
#  [2172, 317],
#  [72311, 43199, 29, 17731, 3, 769],
#  [72312],
#  [72313],
#  [4, 162, 2, 7467, 64],
#  [2237, 281, 417, 3187, 17732, 8966, 146, 72314, 5592, 274],
#  [24960, 43200, 43201, 72315, 72316, 271, 31505, 72317],
#  [269, 173, 72318, 72319],
#  [11361, 323, 419, 4553, 595, 49],
#  [43202, 72320, 6121, 72321],
#  [1112, 3841, 146, 67],
#  [2358, 2511, 8967, 72322, 14, 31506, 43203, 1523, 4745],
#  [2089],
#  [43204, 43205],
#  [110, 180, 674, 72323, 1056, 1056, 457],
#  [4086, 1118, 2131, 75, 10, 756, 1, 1002, 43206, 3367],
#  [1587, 515, 552, 332, 4385, 12475, 17733],
#  [10437, 89, 5593, 72324, 72325, 43207, 72326, 1462],
#  [73, 47, 72327, 72328],
#  [197],
#  [1161, 7056, 224, 72329, 72330, 43208, 12, 12476, 67, 25, 12, 43209],
#  [136, 3188],
#  [9620, 43210, 3189, 54, 106],
#  [4746, 215, 12477],
#  [577, 2292, 43211, 118, 433, 43212, 827, 15420],
#  [190, 1238, 46, 1],
#  [11362,
#   521,
#   15421,
#   24961,
#   9621,
#   31507,
#   878,
#   5831,
#   24962,
#   43213,
#   6122,
#   861,
#   2237,
#   43214,
#   149,
#   3527,
#   7,
#   2671,
#   6729,
#   72331,
#   4554],
#  [6, 15422, 17734, 4386, 2000, 65, 72332, 11363, 1855, 483, 930, 24, 1769],
#  [72333, 31508, 715, 43215, 462, 7468, 113, 389],
#  [72334],
#  [589],
#  [1798, 285, 699, 2090, 31509, 2132],
#  [266, 35, 7, 5356, 12478],
#  [1650, 3450, 42, 2816, 1, 438, 17, 683, 794, 104, 53, 24963, 17735, 11364],
#  [72335,
#   72336,
#   439,
#   16,
#   490,
#   122,
#   72337,
#   7469,
#   83,
#   43216,
#   72338,
#   34,
#   72339,
#   12,
#   1829,
#   72340,
#   24,
#   8968,
#   43217,
#   24964,
#   173,
#   29,
#   1393,
#   72341,
#   2001,
#   1036,
#   4087],
#  [2, 6730, 5132, 1, 578, 52, 72342, 134, 31510],
#  [23, 2293],
#  [43218, 964, 89, 72343],
#  [89, 72344, 316],
#  [1, 43219, 31511, 93, 71, 11365, 20678, 72345],
#  [17736, 72346, 20679, 7884, 5594, 72347],
#  [43220, 7470, 11366],
#  [4916, 5595, 1463, 72348, 148, 10438, 54, 8393, 72],
#  [1679, 468, 24965],
#  [24966, 17737, 72349, 244, 72350, 7471, 43221, 11367],
#  [24967, 3190, 11368, 72351, 11369, 72352, 72353],
#  [12479],
#  [4555, 5133, 2817, 5832, 1, 20680, 1181, 48, 302, 1],
#  [73,
#   72354,
#   72355,
#   43222,
#   31512,
#   72356,
#   20681,
#   72357,
#   72358,
#   3,
#   72359,
#   72360,
#   801,
#   15423,
#   731,
#   72361,
#   153,
#   31513],
#  [10439],
#  [3842, 24961, 72362, 862],
#  [7057, 72363],
#  [5,
#   11,
#   1295,
#   1630,
#   1226,
#   39,
#   247,
#   22,
#   295,
#   1718,
#   6388,
#   10,
#   31514,
#   72,
#   102,
#   24968,
#   645,
#   257,
#   6731,
#   167,
#   9,
#   579,
#   224,
#   129,
#   34,
#   12480,
#   72364,
#   1917,
#   3191,
#   646,
#   7885],
#  [72365, 72366, 72367, 72368, 72369, 72370],
#  [10440, 8, 2413, 351, 158, 15, 56, 81, 157, 198, 1],
#  [23,
#   4,
#   2359,
#   9,
#   3287,
#   14,
#   60,
#   2133,
#   9622,
#   1,
#   6123,
#   887,
#   2818,
#   24969,
#   496,
#   3192,
#   10,
#   1363,
#   1166,
#   84,
#   391,
#   2091,
#   192,
#   2359,
#   9,
#   4387,
#   9,
#   12481,
#   43223,
#   4747,
#   17738,
#   4745,
#   57,
#   72371,
#   48,
#   43224,
#   113,
#   4748],
#  [5596, 3125, 183, 13826, 1799, 4749],
#  [23],
#  [44, 9623, 206, 2567, 163, 72372, 31515, 72373, 17739],
#  [174, 228, 1800],
#  [2, 36, 1],
#  [3, 469, 72374],
#  [1447,
#   31516,
#   72375,
#   647,
#   72376,
#   7,
#   72377,
#   4,
#   72378,
#   20682,
#   161,
#   60,
#   72379,
#   7,
#   13827,
#   31517,
#   5833],
#  [20683, 7886, 72380, 31518, 8969, 72381],
#  [43225, 7, 72382],
#  [69],
#  [72383, 11370, 43226, 53],
#  [72384, 43227, 72385, 1133, 155],
#  [164, 72386],
#  [72387,
#   3193,
#   72388,
#   1524,
#   72389,
#   285,
#   72390,
#   72391,
#   189,
#   72392,
#   7887,
#   72393,
#   43228,
#   3,
#   72394,
#   43229,
#   847,
#   1269,
#   72395,
#   72396,
#   72397],
#  [43230,
#   4385,
#   614,
#   72398,
#   10436,
#   8970,
#   620,
#   72399,
#   43231,
#   5134,
#   43232,
#   72400,
#   17,
#   31519,
#   72401,
#   4917,
#   3,
#   72402,
#   72403,
#   72404,
#   189,
#   24970,
#   20684,
#   37,
#   20685,
#   78,
#   72405,
#   599,
#   72406,
#   772,
#   614],
#  [1, 72407, 43233, 11371, 3069, 72408, 43234],
#  [6124, 12482, 457],
#  [72409, 64, 11372, 72410, 72411, 675, 1801, 72412],
#  [24971, 15424, 1588, 7058, 31520, 75, 716, 26, 72],
#  [31521],
#  [9624,
#   72413,
#   72414,
#   10441,
#   17740,
#   17741,
#   165,
#   253,
#   1976,
#   66,
#   17742,
#   5597,
#   101,
#   72415,
#   414,
#   2,
#   72416,
#   70,
#   116,
#   1121,
#   3528,
#   4750],
#  [1651,
#   374,
#   3529,
#   31522,
#   2092,
#   7472,
#   8971,
#   72417,
#   238,
#   43235,
#   1697,
#   6125,
#   2,
#   15425,
#   1068,
#   6389,
#   6732,
#   43236,
#   72418,
#   173,
#   17743,
#   2473,
#   12483,
#   1296,
#   72419,
#   72420,
#   1407,
#   20686,
#   199,
#   72421,
#   752],
#  [9625, 13828, 1477, 2940, 6390],
#  [72422, 470, 1830],
#  [72423],
#  [5, 1, 13829, 25, 7, 4221, 1770, 1887, 9626, 5, 18, 6126, 31523, 152, 72424],
#  [72425, 193],
#  [3, 125, 1, 480],
#  [2093, 1953, 15426, 31524, 81, 724, 31525, 758, 1034],
#  [24972, 24972, 13, 43237, 163, 24973],
#  [3,
#   31526,
#   6391,
#   20687,
#   360,
#   72426,
#   124,
#   31527,
#   5357,
#   72427,
#   12484,
#   2206,
#   43238,
#   72428,
#   3070,
#   7888,
#   322,
#   72429,
#   72430,
#   43239,
#   20688,
#   314,
#   31528],
#  [72431, 3, 2055],
#  [501,
#   1478,
#   1954,
#   207,
#   136,
#   43240,
#   1918,
#   280,
#   72432,
#   1255,
#   57,
#   284,
#   72433,
#   15427,
#   2,
#   9627,
#   700,
#   276,
#   1680,
#   1364,
#   298,
#   862,
#   6,
#   72434,
#   3746,
#   648],
#  [240, 11373, 72435],
#  [72436, 72437, 7059, 7473, 44, 43241, 2670, 1479, 114],
#  [5135],
#  [537, 176, 2360, 4088],
#  [72438, 790, 72439, 72440],
#  [31529,
#   72441,
#   1113,
#   72442,
#   149,
#   7,
#   72443,
#   24974,
#   31530,
#   24975,
#   31531,
#   705,
#   8972,
#   72444,
#   43242,
#   31532,
#   43243,
#   72445,
#   5596,
#   24976],
#  [43244, 72, 72446, 15, 158],
#  [39, 8973, 22, 1],
#  [2294, 2, 1919, 110, 222, 837, 11374, 190, 43245, 10442, 72447],
#  [3843, 4556, 15428, 72448, 24977, 4557, 43246, 31533, 2, 6733, 1],
#  [47, 72449, 72450, 5358, 43247, 199, 279, 72451, 72452, 72453],
#  [72454, 1609, 7889, 163, 72455, 9628, 72456, 2941, 10443],
#  [174, 5598, 72457, 72458, 879, 72459, 20689],
#  [949, 72460, 10444],
#  [35, 72461, 72462, 581, 476, 4388, 72463, 43248, 24978, 82],
#  [76, 972, 64, 53, 24979, 279, 31534, 106, 76, 2056, 72464],
#  [2878,
#   24980,
#   196,
#   10,
#   37,
#   3007,
#   24981,
#   5,
#   1037,
#   24982,
#   42,
#   12485,
#   72465,
#   17,
#   43249,
#   72466,
#   24983,
#   196,
#   10,
#   37,
#   188,
#   2474],
#  [12486, 13830, 406, 1610, 2743, 2414],
#  [31535, 189, 263, 72467, 72468, 72469],
#  [72470, 15429, 72471, 72472, 104],
#  [43250,
#   72473,
#   15430,
#   15431,
#   31536,
#   43251,
#   31537,
#   72474,
#   9629,
#   72475,
#   43252,
#   31538,
#   72476,
#   2879,
#   9,
#   72477,
#   57,
#   7474,
#   539,
#   43252,
#   207,
#   72478,
#   72479,
#   4389,
#   72480,
#   9,
#   31510,
#   72481],
#  [43253, 57, 326, 3530, 462, 72482, 72483, 72484],
#  [31539, 43254, 34, 43255, 72485],
#  [23, 3, 43256, 2, 6734, 72486, 3844, 288, 3, 348],
#  [31540, 1831, 158],
#  [72487],
#  [43257, 257, 9630, 11375, 1],
#  [335, 1],
#  [24, 86, 880, 27, 6, 2568, 387],
#  [20690, 98, 1155, 281, 221, 17744],
#  [44, 72488, 12487, 3, 4089, 17, 72489, 72490, 45],
#  [502, 13831],
#  [32, 72491, 72492, 1408, 15432, 72493, 172],
#  [23, 2, 900, 6127, 72494, 39, 43258, 5, 1, 418],
#  [1548, 314, 5359, 1, 44, 508, 429, 9631, 27],
#  [72495, 20691, 20692, 7060, 1631, 3649, 61, 6735, 333],
#  [11376, 7061, 72496, 2361, 43259, 1],
#  [72497,
#   43260,
#   72498,
#   5834,
#   1020,
#   72499,
#   42,
#   72500,
#   293,
#   105,
#   105,
#   449,
#   105,
#   105,
#   4390,
#   105,
#   105,
#   17745,
#   26,
#   28],
#  [173, 96, 1100, 2, 33, 1771, 15433],
#  [513,
#   116,
#   275,
#   72501,
#   80,
#   11377,
#   165,
#   4558,
#   4751,
#   261,
#   4918,
#   24984,
#   244,
#   26,
#   64],
#  [7475, 3, 38, 2569, 12488, 38, 3, 1464],
#  [2057, 2819, 8974, 915],
#  [318, 72502, 24985, 72503, 235, 390, 1800],
#  [72504, 20693, 11378, 1480, 773, 11378],
#  [24986, 942, 9, 366, 172],
#  [11,
#   12489,
#   3531,
#   20694,
#   6736,
#   124,
#   72505,
#   3194,
#   17746,
#   233,
#   42,
#   1057,
#   1,
#   72506,
#   72507,
#   72508,
#   24987,
#   2880],
#  [72509, 631, 7890, 2, 4391],
#  [72510,
#   1020,
#   3195,
#   311,
#   8394,
#   8,
#   790,
#   8395,
#   308,
#   145,
#   13832,
#   72511,
#   206,
#   338,
#   4090,
#   68,
#   20695,
#   72512,
#   8975,
#   1,
#   3747,
#   72513,
#   24988,
#   72514,
#   432],
#  [392, 72515, 13833, 7062, 72516, 6392],
#  [348,
#   4,
#   8976,
#   72517,
#   72518,
#   24989,
#   72519,
#   43261,
#   72520,
#   13834,
#   43261,
#   592,
#   8396,
#   43262,
#   3451,
#   4,
#   72521,
#   6737,
#   140,
#   31541,
#   17747,
#   72522,
#   72523],
#  [72524, 72525, 43263, 72526, 72527, 72528, 72529, 72530, 72531],
#  [43264, 43265, 72532, 43265],
#  [102, 8, 3532, 635],
#  [14, 31542, 93, 5360, 78, 5835, 13, 248],
#  [72533, 72534, 10445, 72535, 72536, 14, 6128, 307],
#  [72537, 72538, 72539, 31543, 67],
#  [13835, 2295, 24990, 243, 782, 43266],
#  [17748, 32, 372, 8977, 623, 15434, 49],
#  [72540, 31544, 72541, 3533, 1344, 91],
#  [7476, 6393, 2942, 1498, 1430, 268, 72542],
#  [5361, 6738, 937, 6129, 72543, 72544, 596, 9632],
#  [425, 217, 72545, 143, 72546, 3008, 7063, 1802, 72547, 67],
#  [4752, 72548, 17749, 9633, 460, 2672, 27],
#  [1021, 807, 153, 43267, 39, 2820, 24991],
#  [211, 43268, 72549],
#  [4, 4392, 553, 10, 557],
#  [447, 40, 2475, 1955, 324, 1569],
#  [43269, 24992, 31545, 72550, 1803, 72551, 2512, 4, 3071, 1431],
#  [28, 2, 72552],
#  [72553],
#  [38, 99],
#  [8, 1, 1270, 31546, 1020, 5836, 72554, 68],
#  [72555, 921, 1499, 1477, 43270],
#  [11379, 13836, 17750, 11379, 13836, 17750],
#  [43271, 2204, 116],
#  [7477, 114, 2022, 1772, 64, 2415, 2022, 1772, 24993, 3967],
#  [72556, 1],
#  [43272,
#   72557,
#   17751,
#   72558,
#   20696,
#   13837,
#   377,
#   12490,
#   7064,
#   5837,
#   72559,
#   31547,
#   173,
#   72560],
#  [447, 40, 7, 30, 72561],
#  [23, 965, 112, 20, 20697, 58, 67, 4, 625, 4, 72562],
#  [12491, 58, 96, 4753, 2134, 2570, 5599, 444],
#  [4393, 1211, 407, 24994],
#  [1, 72563, 68],
#  [9634,
#   343,
#   72564,
#   24995,
#   1743,
#   43273,
#   2,
#   31548,
#   72565,
#   72566,
#   1134,
#   24996,
#   219,
#   24997,
#   1,
#   1497,
#   1632,
#   75,
#   931,
#   427],
#  [17752, 161, 132, 10446, 1956, 3650, 27],
#  [29, 146, 72567, 29, 881, 385],
#  [17753, 72568, 3368],
#  [774],
#  [2296, 8978, 31549, 72569, 72570],
#  [35, 1888, 24998],
#  [956, 279, 20698, 12, 7478, 266, 8397, 20698],
#  [3, 370, 398, 72571, 1],
#  [15435,
#   705,
#   411,
#   294,
#   43274,
#   981,
#   72572,
#   72573,
#   103,
#   1652,
#   1773,
#   4919,
#   24999,
#   43275],
#  [25000,
#   3534,
#   38,
#   20699,
#   1345,
#   43276,
#   5838,
#   1719,
#   1101,
#   180,
#   31550,
#   6394,
#   432],
#  [35, 1653],
#  [4559],
#  [4222, 3748, 41, 1213, 41, 94, 254, 72574],
#  [313,
#   2058,
#   359,
#   1432,
#   372,
#   3651,
#   323,
#   815,
#   95,
#   20700,
#   72575,
#   31551,
#   293,
#   1309,
#   711,
#   2821,
#   17754,
#   1271,
#   423,
#   932,
#   25001,
#   43277],
#  [2237, 72576, 340, 682, 66, 179, 107, 5839],
#  [649, 72577, 72578, 67, 3072, 916, 299],
#  [17755,
#   25002,
#   72579,
#   16,
#   6,
#   72580,
#   8979,
#   102,
#   973,
#   20701,
#   400,
#   712,
#   5136,
#   783,
#   31552,
#   72581,
#   16,
#   43278,
#   72582,
#   43278,
#   72583,
#   72584,
#   5137,
#   341],
#  [143, 72585, 72586, 48, 43279],
#  [56, 15, 56, 2673, 43280, 12],
#  [8, 18, 1135, 43281, 2821, 3652, 496, 8398, 31553, 1977, 9635, 1045, 1],
#  [3288],
#  [146,
#   86,
#   744,
#   1957,
#   25003,
#   17756,
#   72587,
#   2238,
#   72588,
#   72589,
#   813,
#   84,
#   1114,
#   7479],
#  [17757, 15436, 20702, 901, 6395, 3968],
#  [40,
#   2,
#   1003,
#   83,
#   11380,
#   650,
#   1500,
#   5138,
#   3369,
#   8,
#   4223,
#   18,
#   6130,
#   72590,
#   9636,
#   6130,
#   10447,
#   83,
#   186,
#   539,
#   8980,
#   70,
#   902,
#   308,
#   43282,
#   72591,
#   43283,
#   15,
#   5,
#   11,
#   411,
#   669,
#   8399],
#  [43284, 131, 28],
#  [72592, 72593, 72594, 853, 72595],
#  [24,
#   2206,
#   3192,
#   72596,
#   838,
#   43285,
#   72597,
#   88,
#   72598,
#   31554,
#   3969,
#   72599,
#   31554,
#   2744,
#   7065,
#   1744,
#   12492,
#   32,
#   72600,
#   6396,
#   56,
#   52,
#   10448,
#   1633,
#   72601,
#   3196,
#   7891],
#  [72602, 204, 651, 1],
#  [53, 2476],
#  [293,
#   1365,
#   55,
#   43286,
#   119,
#   603,
#   65,
#   72603,
#   138,
#   72604,
#   72605,
#   15437,
#   10449,
#   25004],
#  [5, 1, 3, 43287, 296, 8978],
#  [839, 356, 503, 25005],
#  [31555, 3, 271, 43288, 72606, 11381, 1136, 8981, 2943, 44, 31555, 72607],
#  [1461, 31556, 20703, 43289, 1102, 43290, 25006, 3845, 117, 23, 1525],
#  [4224,
#   943,
#   52,
#   19,
#   1654,
#   3370,
#   2411,
#   20704,
#   78,
#   152,
#   7480,
#   3,
#   72608,
#   1655,
#   25007,
#   12493,
#   4394,
#   72609,
#   49,
#   3,
#   1022,
#   109],
#  [43291, 72610, 72611, 9637, 77, 656],
#  [1679, 468, 14, 72612],
#  [5840, 1297, 31557, 370, 11382, 100, 86, 27],
#  [43292, 102, 973, 25008, 6131, 7481, 22, 1, 584, 72613, 1394, 10450, 2944],
#  [88, 32, 2617, 2362, 7066, 72614],
#  [46, 2135, 43293, 3535, 327],
#  [99, 528],
#  [108, 331, 421, 11383],
#  [43294,
#   72615,
#   225,
#   72616,
#   1361,
#   377,
#   43295,
#   72617,
#   531,
#   72618,
#   640,
#   43296,
#   130,
#   3,
#   72619,
#   51],
#  [1632, 2513, 732, 72620],
#  [1323, 10, 26, 72621, 72622, 43297, 72623],
#  [72624,
#   103,
#   12494,
#   43298,
#   43299,
#   254,
#   31558,
#   3,
#   5841,
#   17758,
#   11384,
#   72625,
#   53,
#   8400,
#   438,
#   139,
#   957,
#   1745],
#  [12495, 579, 10451, 72626, 249, 31559, 1256, 25009, 72627],
#  [23, 72628, 25010, 111, 72629],
#  [7482,
#   72630,
#   72631,
#   72632,
#   35,
#   31560,
#   93,
#   20705,
#   1,
#   1285,
#   31561,
#   263,
#   20706,
#   43300,
#   3536,
#   72633,
#   72634,
#   72635,
#   43301],
#  [1501, 568, 917],
#  [20707, 393, 21, 72636, 13838, 43302],
#  [72637],
#  [25011,
#   72638,
#   274,
#   19,
#   7892,
#   14,
#   20708,
#   1409,
#   181,
#   6397,
#   3846,
#   5362,
#   267,
#   1502,
#   349,
#   206,
#   1346,
#   12,
#   9638],
#  [20709,
#   2477,
#   7483,
#   43303,
#   37,
#   6739,
#   481,
#   43304,
#   1346,
#   12,
#   232,
#   72639,
#   17759,
#   1447,
#   201,
#   4754,
#   271,
#   25012,
#   218,
#   198,
#   253,
#   244,
#   27],
#  [3970, 187, 13, 43305, 156, 1920, 1889],
#  [31562, 366, 72640, 72641, 72642],
#  [43306, 1656],
#  [23, 72643, 8982, 950, 31563, 1324],
#  [944, 17760],
#  [20710, 1, 1978, 72644, 72645],
#  [97, 453, 176, 541, 72646, 3073],
#  [36, 43307, 1856, 3197, 72647],
#  [25013, 72648, 2745, 72649],
#  [31564],
#  [72650, 52, 789, 72651, 3126, 2239, 3192, 553, 10, 756, 117],
#  [13839, 2, 662, 1, 72652, 9, 72653, 72654, 9, 72655],
#  [11385, 72656, 43308, 72657, 72658, 72659, 854, 1],
#  [88, 795, 593, 205, 2674],
#  [7484, 72660, 72661],
#  [2416, 72662, 115, 1180, 5363, 51],
#  [2746],
#  [152, 3009, 83, 72663, 966],
#  [72664, 72665, 72666],
#  [2618, 174, 43309, 43310, 25014, 14, 662, 43311],
#  [5364, 72667, 47, 72668, 72669, 72670, 13840],
#  [554, 2173, 72671, 72672],
#  [1058, 154, 72673, 15438, 903],
#  [19, 434, 2417, 72674, 1325, 9, 17761, 18, 10452, 3653],
#  [231,
#   103,
#   1257,
#   93,
#   249,
#   12496,
#   25015,
#   72675,
#   4389,
#   6740,
#   25015,
#   31565,
#   72676,
#   72677,
#   43312,
#   72678],
#  [72679,
#   2136,
#   72680,
#   31566,
#   2,
#   43313,
#   72681,
#   72682,
#   945,
#   17762,
#   72683,
#   72684,
#   386,
#   418,
#   72685,
#   603,
#   2297,
#   72686,
#   547,
#   72687,
#   43314,
#   13841,
#   34,
#   72688,
#   25016,
#   72689,
#   2,
#   43313,
#   43315,
#   43316,
#   72690,
#   3371],
#  [888, 1, 1286, 72691, 72692, 2478, 2207, 8401],
#  [944, 1023],
#  [447],
#  [116, 372, 29, 306, 29, 1239, 469],
#  [31567, 26, 1004, 72693, 72694, 882, 8402],
#  [3289, 153, 175, 1],
#  [43317,
#   244,
#   26,
#   1197,
#   362,
#   3654,
#   31568,
#   15439,
#   403,
#   6132,
#   17763,
#   2569,
#   4086,
#   72695],
#  [179, 206, 631, 264, 370, 6398, 903],
#  [72696, 72697, 6399, 43318, 72698, 1774, 72699, 43319, 4225],
#  [73],
#  [25017, 72700],
#  [72701, 93, 72702, 72703],
#  [1112, 101, 4560, 17764, 922],
#  [3970, 26, 2328, 327, 2002, 3010, 10453, 11386, 25018, 1],
#  [5, 18, 184, 6, 7893, 188, 196, 4561],
#  [25019, 20711, 72704, 406, 3749, 2479, 901],
#  [43320, 439, 72705, 48, 15440, 50, 334, 8983, 12497, 168],
#  [149,
#   440,
#   8984,
#   1804,
#   65,
#   5600,
#   2174,
#   8403,
#   25020,
#   593,
#   407,
#   72706,
#   1035,
#   130,
#   580,
#   2023,
#   72707,
#   56,
#   580,
#   689,
#   40,
#   3198,
#   6741],
#  [7,
#   5365,
#   13842,
#   72708,
#   1227,
#   1746,
#   1046,
#   840,
#   25021,
#   43321,
#   72709,
#   34,
#   4562,
#   17765,
#   3750,
#   55,
#   34,
#   7,
#   159,
#   12,
#   8404,
#   4395,
#   1059,
#   15441,
#   31569,
#   43322,
#   9639,
#   27,
#   282,
#   72710,
#   20712,
#   7,
#   990],
#  [2675, 3847, 3074, 255, 46, 1, 12, 15, 2881, 3, 31570, 1, 43323],
#  [2208,
#   43324,
#   12498,
#   482,
#   1103,
#   422,
#   8985,
#   320,
#   31571,
#   231,
#   1182,
#   1245,
#   1921,
#   25022,
#   72711,
#   222,
#   1,
#   4563,
#   22,
#   331,
#   25023,
#   1],
#  [72712, 72713],
#  [2059,
#   147,
#   43325,
#   1347,
#   20713,
#   222,
#   294,
#   717,
#   2,
#   96,
#   308,
#   95,
#   828,
#   519,
#   1634,
#   8986,
#   17,
#   2298,
#   7,
#   234,
#   216,
#   20714,
#   72714,
#   25,
#   2290,
#   15442,
#   72715,
#   43326,
#   375,
#   174,
#   17766,
#   12499,
#   72716,
#   85],
#  [72717, 20715, 17767, 43327, 72718, 701, 17768, 43328],
#  [1, 4, 15, 20716, 72719, 6133],
#  [297, 9, 72720, 72721, 72722],
#  [2676, 1346, 20717, 17769, 17, 7067, 6134, 125, 566, 8966, 2137],
#  [15443, 43329, 430, 72723, 8987, 1503, 3655, 3, 25024, 470, 491, 44, 72724],
#  [2299, 90, 146, 2514, 72725, 4],
#  [31572, 11368],
#  [31573, 2476, 8988, 1287, 72726, 808, 15444, 15445, 72727, 5139],
#  [17770, 72728, 72729],
#  [153, 4396, 72730, 165, 2175, 37, 1],
#  [4, 6742, 1410, 202, 1188, 1012, 168],
#  [72731,
#   25025,
#   144,
#   12475,
#   182,
#   12,
#   8405,
#   450,
#   945,
#   72732,
#   188,
#   9640,
#   1326,
#   83,
#   1805,
#   225,
#   7068,
#   25026,
#   72733,
#   3069,
#   1958,
#   72734,
#   17771,
#   2297,
#   7069,
#   31574,
#   4920,
#   72735,
#   190,
#   43330,
#   205,
#   15446],
#  [2822, 483, 72736, 72737],
#  [1258],
#  [213, 3, 110, 180],
#  [25027,
#   11387,
#   72738,
#   340,
#   5601,
#   43331,
#   8,
#   11,
#   166,
#   775,
#   3848,
#   1411,
#   1504,
#   1523,
#   93,
#   72739,
#   334,
#   43332,
#   72740,
#   37,
#   863,
#   60,
#   72741],
#  [72742, 6743, 69, 1240, 375, 229, 21, 3127, 7060, 72743, 72744],
#  [1959, 197, 12500, 1481, 10454],
#  [3,
#   72745,
#   12501,
#   737,
#   20718,
#   3199,
#   133,
#   1057,
#   72746,
#   72747,
#   8989,
#   43333,
#   399,
#   31575,
#   340,
#   1298],
#  [3011, 246, 3537, 5842, 20719],
#  [43, 132, 1681, 1060, 105, 6400, 26, 974, 6, 72748, 72749],
#  [6, 12502, 2024],
#  [1189,
#   43334,
#   932,
#   5140,
#   158,
#   3,
#   5,
#   1,
#   72750,
#   1465,
#   156,
#   230,
#   39,
#   1698,
#   3849,
#   25028,
#   155,
#   3971,
#   43335,
#   3128,
#   59,
#   203,
#   864,
#   72751],
#  [5843, 13843, 22, 132, 1],
#  [816,
#   125,
#   1,
#   621,
#   662,
#   7894,
#   37,
#   775,
#   5,
#   18,
#   43336,
#   11388,
#   43337,
#   14,
#   9,
#   3751,
#   52,
#   1122,
#   9641,
#   4564,
#   1146,
#   43338,
#   5844,
#   678],
#  [43339, 570, 171, 72752, 19, 148, 72753],
#  [44, 72754, 44, 12503, 72755],
#  [72756],
#  [72757, 25029, 20720, 1433, 25030],
#  [14, 43340, 72758, 72759, 11389, 1806],
#  [23, 72760, 72761],
#  [738, 53],
#  [97, 43341, 8, 72762, 72763, 3200, 2882],
#  [5141, 2138, 3752, 1832, 5845],
#  [157, 220, 1549, 6744, 72764, 72765, 1],
#  [2883, 223, 1807],
#  [72766, 31576, 319],
#  [99, 1288, 571, 31577],
#  [72767,
#   72768,
#   72769,
#   72770,
#   72771,
#   231,
#   72772,
#   31578,
#   1699,
#   72773,
#   1682,
#   610,
#   72774,
#   43342,
#   72775,
#   72776],
#  [2363, 1635, 1165, 1635, 119, 1635, 394, 116],
#  [43343, 4091, 13844],
#  [43344, 11390, 1395, 12504, 43345],
#  [2, 2240, 335, 1, 3, 15447],
#  [1857],
#  [20721,
#   6745,
#   1634,
#   8406,
#   72777,
#   72778,
#   29,
#   25031,
#   72779,
#   15448,
#   72780,
#   20722,
#   31579,
#   72781,
#   88,
#   5602,
#   9,
#   72782,
#   17772,
#   2300,
#   25032,
#   72783,
#   1653],
#  [43346],
#  [5603, 933, 4921, 5603, 8990, 560, 72784, 25033],
#  [6, 184],
#  [72785,
#   2884,
#   13,
#   72786,
#   369,
#   72787,
#   4561,
#   513,
#   72788,
#   3849,
#   72789,
#   72790,
#   72791,
#   72792,
#   327,
#   72793,
#   555,
#   72794,
#   162,
#   6401,
#   20723,
#   72795,
#   72796,
#   72797],
#  [164, 72798, 7485, 20, 5142],
#  [604, 737, 604],
#  [170, 958, 6135],
#  [43347, 9642, 4755, 5, 120, 43348, 532, 6136],
#  [19, 136, 27],
#  [72799,
#   8991,
#   25034,
#   72800,
#   25034,
#   8407,
#   1922,
#   8408,
#   3452,
#   4226,
#   72801,
#   72802,
#   43349],
#  [72803, 72804, 72805],
#  [121, 72806, 1, 156, 230, 1550, 3201],
#  [72807, 72808, 6402, 166, 1],
#  [25035, 72809, 1228],
#  [11391, 156, 55, 1285, 2329, 7070, 57, 72810, 27],
#  [208, 72811, 72812, 1327, 9643, 403, 5604, 77, 1229],
#  [7071, 548, 7072, 548, 128, 13845],
#  [1551, 76, 4092],
#  [4397, 865, 60, 9, 7073, 31580, 10455, 72813, 31581],
#  [3, 3850, 53, 72814, 25036, 38, 2, 506],
#  [533, 256, 54, 20, 1],
#  [25037,
#   15,
#   14,
#   20724,
#   1,
#   159,
#   2,
#   3129,
#   43350,
#   72815,
#   43351,
#   364,
#   98,
#   15449,
#   43352,
#   72816,
#   15450,
#   20725,
#   72817,
#   43351,
#   159,
#   14,
#   72818,
#   4398,
#   93],
#  [572],
#  [17773, 3453, 72819, 15451, 6, 72820],
#  [72821, 2515, 12, 1552],
#  [179, 483, 119, 6403, 72822, 12505, 15452, 12, 506],
#  [25038, 3, 4565, 343, 2746, 31582, 25039, 17774, 776, 106],
#  [72823,
#   15453,
#   72824,
#   13846,
#   2675,
#   17775,
#   43353,
#   72825,
#   43354,
#   3372,
#   11392,
#   43355,
#   3372,
#   72826,
#   43356,
#   72827,
#   2364,
#   43357],
#  [20726, 3075, 72828, 2418],
#  [25, 32, 7, 3202, 1211, 43358, 6746, 357, 20, 113, 72829, 255, 31583, 16],
#  [73, 72830, 410, 381, 1366, 72831, 702, 72832],
#  [80, 72833, 72834, 144, 343, 13, 180, 1259, 9644, 56, 43359, 1526],
#  [679, 15454, 13847, 533, 3203, 81, 56, 15, 249, 1],
#  [43360, 230, 43361, 26],
#  [17776, 72835, 11393, 13848, 1239, 8992, 72836, 31584, 145, 72837],
#  [814, 626, 2885, 132, 25040, 305],
#  [5,
#   92,
#   43362,
#   72838,
#   3,
#   72839,
#   9645,
#   31585,
#   1122,
#   794,
#   78,
#   4399,
#   72840,
#   15455,
#   6747,
#   841,
#   4227,
#   3,
#   11394,
#   8409,
#   62,
#   72841,
#   72842,
#   6748,
#   5,
#   19,
#   3,
#   5840],
#  [43363, 2677, 2945, 72843, 2946],
#  [335, 64],
#  [375, 72844, 1, 1570],
#  [1571,
#   466,
#   261,
#   305,
#   1482,
#   150,
#   267,
#   72845,
#   1348,
#   15456,
#   4400,
#   974,
#   315,
#   1553,
#   652,
#   412,
#   982],
#  [2747, 3076, 256, 1],
#  [5, 19, 40, 693, 1167, 8993, 160, 160],
#  [991, 43364, 1, 9646, 577, 570],
#  [189, 2886, 15, 5, 19, 6749],
#  [12506, 283, 461, 166, 155, 159, 313, 31586, 2947, 31587, 72846, 25041],
#  [4, 96, 26, 1, 31588, 15457, 43365, 4401, 138, 1],
#  [2094, 9623, 31589, 2948, 271, 72847, 37, 330, 7062, 4093],
#  [72848, 43366],
#  [1700,
#   20727,
#   4566,
#   15458,
#   5143,
#   2887,
#   13849,
#   12507,
#   8994,
#   25042,
#   43367,
#   7074,
#   72849,
#   4552,
#   3851,
#   72850,
#   50,
#   85],
#  [72851, 13850, 43368, 1434, 796, 1747, 72852, 168],
#  [375, 25043, 15, 2235, 1916, 9647, 16],
#  [3, 22, 1],
#  [1808,
#   5144,
#   1,
#   561,
#   635,
#   6750,
#   6404,
#   9648,
#   20728,
#   6405,
#   2301,
#   43369,
#   1412,
#   31590,
#   3656],
#  [25044, 31591, 1367, 25045],
#  [466,
#   141,
#   38,
#   7075,
#   105,
#   72853,
#   267,
#   153,
#   76,
#   175,
#   520,
#   1123,
#   1260,
#   4756,
#   72854],
#  [31592, 72855, 292, 5145],
#  [72856, 72857, 72858, 3012, 72859, 72860, 72861, 1589, 72862, 72863],
#  [4094, 106, 569, 31593, 31594, 130, 4095, 55, 848, 8410, 777, 32],
#  [2571, 2480, 92, 17777, 6751, 285, 72864, 1],
#  [4, 43370, 647, 25046, 25047, 72865, 1162, 72866, 625, 4],
#  [72867, 349, 43371, 2678, 43372],
#  [43373, 1272, 72868],
#  [5146, 17778, 72869, 7486, 1572, 42, 491],
#  [72870, 43374, 72871, 17779],
#  [72872, 107, 31595, 581, 529, 463, 31596, 72873, 15459, 4096],
#  [72874, 72875],
#  [630, 1890, 2, 58, 7487, 7488, 1],
#  [62, 31597, 45, 16, 72876, 31598, 4402, 51],
#  [72877, 72878],
#  [528, 72879, 266, 72880, 45],
#  [46, 3204, 12508, 3972],
#  [883, 5846, 77, 975, 43375, 1, 115, 105, 3454, 6406, 13851],
#  [7076],
#  [7489,
#   72881,
#   298,
#   156,
#   55,
#   2176,
#   72882,
#   72883,
#   72884,
#   4,
#   72885,
#   12,
#   54,
#   458,
#   4,
#   31599,
#   142,
#   25048,
#   5605,
#   72886,
#   4922,
#   255,
#   3538,
#   17780,
#   8995],
#  [43376, 1917, 20729, 917],
#  [25, 20, 13852, 115, 1168, 573],
#  [44, 1775, 544],
#  [3205, 2679, 1, 1979, 1748, 15, 43377, 39, 72887],
#  [6, 72888, 14, 9, 6752, 654, 1169, 5847, 214, 90, 43378],
#  [6,
#   3077,
#   13853,
#   9,
#   12509,
#   5147,
#   18,
#   654,
#   2,
#   72889,
#   72890,
#   72891,
#   25049,
#   20730,
#   8411,
#   72892,
#   6137,
#   9649,
#   139,
#   250,
#   3973],
#  [215, 335, 1],
#  [72893, 5, 11, 20731],
#  [3753, 31600, 367, 429, 1261, 2949, 2365, 848],
#  [240, 32, 15, 9650, 72894],
#  [31601, 72895],
#  [72896, 72897, 72898, 72899, 6122, 72900, 43379],
#  [72901, 2748, 468, 2481, 4923, 72902, 1554, 13854, 12510, 250, 114],
#  [274, 718, 43380],
#  [4219, 173, 6753, 31602, 4567, 2888, 3290, 7895, 43381, 8996],
#  [1161, 3539, 1069, 1328, 72903, 641, 20732, 17781, 72904],
#  [189, 43382, 76, 447, 7, 6728, 72905, 1005, 958, 7490],
#  [141,
#   38,
#   1501,
#   125,
#   155,
#   72906,
#   20733,
#   72907,
#   7491,
#   43383,
#   417,
#   3455,
#   4403,
#   72908,
#   72909,
#   20734,
#   108,
#   72910,
#   17782,
#   3373,
#   72911,
#   770,
#   604,
#   31603,
#   31604],
#  [31605,
#   47,
#   32,
#   72912,
#   8412,
#   72913,
#   2366,
#   72914,
#   72915,
#   3,
#   72916,
#   72917,
#   43384,
#   72918,
#   25,
#   72919,
#   20735],
#  [35, 102, 40, 72920, 889],
#  [2950,
#   43385,
#   10456,
#   43386,
#   415,
#   31606,
#   670,
#   43387,
#   12511,
#   3657,
#   20736,
#   72921,
#   72922,
#   363],
#  [31607, 72923, 3754, 72924, 6754, 72925, 72926],
#  [69, 3456],
#  [5606, 10457, 6407, 5848, 25050],
#  [490, 72927, 415, 25051],
#  [1891, 501, 8413, 7896, 72928, 1, 85, 72929, 31608, 72930, 51],
#  [3, 6748, 22, 632, 6138, 1],
#  [5148, 549, 1296, 497, 426, 64, 567, 72931, 55, 611, 12512],
#  [4, 410, 72932, 72933, 936, 72934, 2296, 72935, 72936, 72937, 72938],
#  [6, 216, 1246, 53],
#  [43388, 7077],
#  [8414, 43389, 43390, 422, 12513, 43391, 72939],
#  [9651, 5366, 218, 1885],
#  [6, 1980, 25052],
#  [72940],
#  [72941, 72942, 938, 444, 72943],
#  [4, 904, 1],
#  [31609,
#   13,
#   13855,
#   101,
#   284,
#   72944,
#   2572,
#   464,
#   7078,
#   4757,
#   719,
#   83,
#   379,
#   80,
#   11377,
#   165,
#   20737],
#  [974],
#  [314, 54, 180],
#  [72945, 72946],
#  [25053, 7897, 387, 72947, 72948, 156, 91],
#  [72949, 161, 72950, 64, 2290, 43392, 37, 72951, 5607],
#  [12514, 7492, 4924, 31610, 14, 43393],
#  [25054, 720, 21, 3, 54, 13, 246, 3755, 2419, 20, 1, 115, 3013],
#  [17783, 21, 25055, 79, 72952, 6755],
#  [43394, 8997, 72953, 1273, 43395, 379, 17784, 123],
#  [6408, 521, 753, 38, 649, 38, 2, 1329],
#  [2003,
#   2510,
#   1430,
#   251,
#   72954,
#   31611,
#   8415,
#   72955,
#   72956,
#   6756,
#   72957,
#   72958,
#   14,
#   72959,
#   72960,
#   13856],
#  [8416, 1448, 109, 226, 182, 128, 20738],
#  [5849, 2510, 675, 25056, 110, 951],
#  [72961, 72962, 31612, 1573, 1744, 539, 13857],
#  [72963, 72964, 72965, 72966, 315, 43396],
#  [185,
#   72967,
#   72968,
#   2025,
#   72969,
#   11395,
#   1,
#   1892,
#   72970,
#   20739,
#   20740,
#   4568,
#   25057,
#   10458,
#   193,
#   13858,
#   43,
#   225,
#   4228,
#   72971,
#   25058,
#   193,
#   72972,
#   8417,
#   7493,
#   1,
#   72973],
#  [582, 468, 15, 249, 31613, 10459],
#  [86, 880, 27, 585, 3078, 25, 2482, 31614, 50, 43397, 9652],
#  [471, 72974, 9653, 3374, 563, 1118, 72975, 72976, 72977, 563, 43398],
#  [1809, 44, 2055],
#  [17785],
#  [44, 1163, 72978],
#  [228, 1],
#  [189, 274],
#  [577,
#   31,
#   842,
#   43399,
#   5367,
#   18,
#   3206,
#   4925,
#   148,
#   31615,
#   15460,
#   72979,
#   11396,
#   1923,
#   38,
#   1590,
#   1858,
#   590,
#   1859,
#   74,
#   1413,
#   1156,
#   56,
#   275,
#   9654,
#   801,
#   8418],
#  [17786, 191, 1198, 2241, 15461, 72980],
#  [12515, 12515],
#  [15462, 313, 72981, 135, 15463, 1591, 43400],
#  [6, 9655, 72982],
#  [1449, 4926, 72983, 72984, 31616, 22, 17787, 72985, 4563, 31617, 72986],
#  [72987, 72988, 3540],
#  [1102, 72989, 72990, 1657, 7079, 4404],
#  [24, 1038, 7898, 10, 26, 72991, 4, 5850, 58],
#  [43401, 72992, 3974, 1, 327, 43402, 2, 9656, 990],
#  [72993, 1611, 13859],
#  [279,
#   703,
#   25059,
#   12516,
#   703,
#   72994,
#   43403,
#   776,
#   74,
#   7080,
#   770,
#   30,
#   2058,
#   12517,
#   177],
#  [72995, 2951, 43404, 72996],
#  [1104, 3, 164, 15464, 9657, 68, 10436, 3658],
#  [72997, 31618, 27],
#  [20741, 3541, 357, 167, 1981, 469, 814, 1683, 72998, 25060, 1365, 4569, 7081],
#  [36, 3291, 12518, 141],
#  [43405, 357, 1527, 72999, 2177],
#  [73000,
#   74,
#   17788,
#   10460,
#   1776,
#   463,
#   82,
#   816,
#   13822,
#   1,
#   1497,
#   6409,
#   25061,
#   122,
#   4758,
#   889,
#   144,
#   50,
#   85],
#  [73001,
#   43406,
#   36,
#   31619,
#   642,
#   73002,
#   73003,
#   11397,
#   13860,
#   1831,
#   5,
#   6745,
#   73004,
#   17,
#   25062,
#   73005,
#   73006,
#   73007,
#   73008,
#   43407,
#   8419,
#   1396,
#   73009,
#   3849,
#   20742,
#   31,
#   164,
#   73010,
#   20,
#   73011,
#   9658],
#  [73012],
#  [4229, 12519, 1061, 17789, 73013],
#  [73014,
#   4759,
#   73015,
#   3756,
#   2749,
#   1002,
#   428,
#   3207,
#   43408,
#   95,
#   4,
#   10461,
#   10462,
#   17790,
#   43409,
#   73016,
#   436,
#   46,
#   1,
#   73017,
#   4,
#   7494,
#   73018,
#   176,
#   73019],
#  [215, 1574, 335, 1],
#  [73020, 256, 6410, 58, 5368, 2060, 9659, 496, 5149],
#  [1247, 73021, 2823, 6411, 31620],
#  [992, 73022, 43410, 99],
#  [2206, 25063, 20743, 580, 248, 73023, 10463, 2330, 31621, 1],
#  [25064, 1498, 331, 73024],
#  [73025, 73026, 73027, 548],
#  [191, 9660, 366],
#  [199],
#  [794, 73028, 42, 73029, 351, 57, 219, 855, 1],
#  [1449, 5851, 73030, 515, 10464, 31622],
#  [45, 9, 73031, 2680, 6412],
#  [73032, 1024, 20744],
#  [73033, 7495, 2026, 43411, 73034],
#  [73035, 17791, 43412, 67],
#  [6413, 6414, 43413, 342, 105, 15, 80, 57, 2750, 596, 6415],
#  [7473, 73036, 11398, 31623, 73037, 8998, 15465, 4, 24953, 13861],
#  [494],
#  [5, 6745, 1006, 73038, 18, 5369, 9, 73039, 325, 615, 20745],
#  [7082, 3852, 31624, 43414],
#  [281, 6139, 441, 73040],
#  [80, 53, 73041, 3542, 4, 73042, 53, 159, 73043, 210, 73044, 17792],
#  [73045, 1199, 1039, 89, 110, 15, 31625],
#  [2095,
#   73046,
#   636,
#   73047,
#   218,
#   3208,
#   20746,
#   73048,
#   2516,
#   73049,
#   257,
#   406,
#   31626,
#   43415,
#   356,
#   200,
#   1397],
#  [1466, 15466, 12501, 31627],
#  [8999, 22, 489, 915, 43416, 4570, 2669, 73050, 124],
#  [39, 247, 22, 1],
#  [4, 6757],
#  [1483,
#   6140,
#   2,
#   8420,
#   1447,
#   31628,
#   4097,
#   3659,
#   73051,
#   73052,
#   23,
#   25065,
#   3457,
#   630,
#   43417,
#   73053,
#   5608,
#   9661,
#   4571],
#  [73054, 73055],
#  [31, 272, 1, 68],
#  [15467, 43418, 20747, 73056, 73057],
#  [13862, 83, 31629, 293, 73058, 1701, 2619, 2242, 12520],
#  [43395, 73059, 13863],
#  [847, 1040, 73060, 9000, 905, 73061],
#  [6758,
#   20748,
#   31630,
#   17793,
#   185,
#   17794,
#   3079,
#   73062,
#   25066,
#   1483,
#   43419,
#   73063,
#   73064,
#   73065],
#  [4, 4927, 474, 2941, 9662],
#  [36, 2178, 1450, 3209, 3853],
#  [266,
#   7,
#   43420,
#   6416,
#   20,
#   7880,
#   73066,
#   1610,
#   3850,
#   89,
#   6,
#   73067,
#   12521,
#   43421,
#   73068],
#  [20749, 2139, 15468, 2952],
#  [182, 73069, 73070],
#  [73071, 13864, 73072],
#  [279, 73073, 51],
#  [382],
#  [73074, 73075, 73076, 73077],
#  [3, 73078, 534, 15, 58, 193],
#  [2140, 31631, 12522],
#  [39, 247, 22, 1, 1650, 73079, 145, 6759, 7083, 1077],
#  [73080],
#  [43422, 4760, 31632, 3292, 378, 5, 92, 462],
#  [1, 1070, 17795, 921, 1349, 73081, 73082, 932, 6141, 1, 25067, 2096],
#  [1212,
#   36,
#   2953,
#   73083,
#   1330,
#   1115,
#   349,
#   2420,
#   73084,
#   56,
#   1777,
#   1057,
#   973,
#   73085,
#   16],
#  [73086, 73087, 3, 2824],
#  [1720, 15469, 1888, 73088],
#  [100, 86, 27],
#  [47, 6142],
#  [8, 19, 31, 87],
#  [6750, 17796, 5370, 5852, 1548, 1702, 330],
#  [25068, 73089, 13865, 82, 82, 73090, 3757, 17797, 1],
#  [5150, 3, 54, 1524, 7899, 73091, 6417, 25069, 57, 312, 133, 7496, 16],
#  [73092, 1013, 73093, 31633, 73094, 11399, 162, 73095],
#  [5853, 3660, 43423, 66, 1701, 73096, 81, 5, 321, 2141, 73097],
#  [494, 12523, 12523, 12523, 12523, 3539],
#  [43424, 73098, 1],
#  [73, 33, 1179, 2367, 73099],
#  [73100, 43425, 31634, 73101, 219, 15440, 5371],
#  [1461, 3543, 59, 906, 1],
#  [4,
#   24,
#   73102,
#   25070,
#   2483,
#   7084,
#   1467,
#   1090,
#   73103,
#   17798,
#   95,
#   24,
#   73104,
#   670,
#   13,
#   3130,
#   3014,
#   2142,
#   69,
#   73105,
#   7,
#   9663,
#   11400,
#   73106,
#   1414,
#   469],
#  [254, 3210, 73107, 7, 1295, 73108],
#  [24947, 135, 475],
#  [191, 8421, 19, 856, 6418, 8422, 11401, 31635, 2671, 73109, 431, 351],
#  [4, 73110, 30, 3211, 13866, 4572, 4, 73111, 73112],
#  [7900, 73113, 73114, 73115],
#  [13867, 73116, 73117, 73118, 9001, 17799],
#  [16, 1833, 13868, 4098, 4928, 31636, 391, 1860],
#  [47, 73, 12524, 20750, 412],
#  [1123, 43426, 1, 73119, 43427, 73120, 13869, 8423, 1960, 7901],
#  [17800, 725],
#  [266, 13870, 73121, 167, 12525, 102, 43428, 43429, 545, 2368, 73122, 889],
#  [73123,
#   73124,
#   15470,
#   5151,
#   4395,
#   20751,
#   73125,
#   236,
#   43430,
#   13871,
#   1214,
#   245,
#   43431,
#   89,
#   73126,
#   73127,
#   73128,
#   236,
#   4099,
#   1435,
#   233,
#   123,
#   126,
#   73129,
#   103,
#   72,
#   967,
#   9002,
#   31637,
#   17,
#   5854,
#   73130,
#   400],
#  [29, 2954, 53, 11402, 73131, 68],
#  [43432, 231, 73132, 17801, 2484],
#  [12526, 13872, 32, 7497, 121, 273, 49],
#  [73133, 13873, 73134],
#  [73135, 73136, 71, 25071, 1296, 7498, 1121, 73137],
#  [43433, 73138, 41, 94, 1612, 6143, 73139, 3661, 484],
#  [154, 726, 58, 111, 52, 7902, 58],
#  [161, 73140],
#  [594, 4, 110, 73141],
#  [73142,
#   62,
#   2209,
#   5372,
#   15471,
#   3,
#   2955,
#   26,
#   1410,
#   3854,
#   8,
#   11,
#   73143,
#   43434,
#   952,
#   701,
#   157,
#   198,
#   1],
#  [162, 3855, 3975, 25072],
#  [25073, 73144, 9, 73145, 73146, 73147, 43435],
#  [73148],
#  [15, 6418, 94, 157, 198, 1],
#  [2369, 1238, 60, 6760, 15472, 7499, 43436, 12527, 73149],
#  [65, 1893, 3976, 248, 1500, 25074, 25075, 73150, 73151, 1],
#  [12528,
#   2476,
#   25076,
#   34,
#   1982,
#   482,
#   25077,
#   4230,
#   7903,
#   73152,
#   73153,
#   759,
#   1,
#   7085,
#   4573,
#   4574,
#   2331,
#   2825,
#   73154,
#   73155,
#   4761,
#   864,
#   1575,
#   188,
#   5152,
#   5153,
#   1041,
#   6761],
#  [73156],
#  [33, 20752, 3544, 542, 17802, 5373, 7086, 2751, 1],
#  [73157, 73158, 73159, 73160, 73161, 66, 1505, 2179, 73162],
#  [73,
#   4575,
#   3545,
#   12,
#   73163,
#   25078,
#   25079,
#   3,
#   73164,
#   2743,
#   73165,
#   73166,
#   1983,
#   2943,
#   297,
#   645,
#   31638,
#   37,
#   73167,
#   5,
#   124,
#   73168,
#   73169,
#   13874,
#   1415,
#   1924,
#   15473,
#   64],
#  [125, 1091],
#  [3, 73170, 73171],
#  [15474, 73172, 521, 31639, 4231, 73173, 31640, 9003, 7904, 73174],
#  [3, 73175],
#  [2370, 4762, 73176, 20753, 1, 20754],
#  [1524,
#   73177,
#   120,
#   73178,
#   73179,
#   794,
#   73180,
#   120,
#   73181,
#   57,
#   189,
#   2681,
#   36,
#   4553,
#   336],
#  [97, 46, 73182, 3, 31641],
#  [25080, 73183],
#  [25081, 142, 739],
#  [47, 43437, 5374],
#  [552, 7500, 9, 1078],
#  [2243, 564, 6762, 17803],
#  [139, 73184, 5154, 1749, 100, 10, 351, 22, 2371],
#  [2244, 754, 93, 1467, 120, 31642],
#  [2296, 17804],
#  [9664, 1658, 73185, 43438, 73186, 3660, 72],
#  [4,
#   8,
#   255,
#   3080,
#   73187,
#   591,
#   71,
#   1,
#   255,
#   1124,
#   31643,
#   4576,
#   25,
#   1147,
#   3545,
#   15475,
#   24,
#   4,
#   73188],
#  [6763, 272, 2027, 9004, 8, 1262, 671, 31, 3370, 50, 772, 404, 1480, 404],
#  [73189, 31644, 73190],
#  [3, 73191, 73192],
#  [9005, 923, 4577, 6764, 15466, 3293],
#  [109],
#  [6, 5609, 9006, 73193, 2826],
#  [43439, 1576, 73194, 73195, 43440, 43441, 4232, 251, 66, 1436, 2, 31645, 68],
#  [111, 12529, 4578, 73196, 73, 111, 1254, 58],
#  [6765, 564, 17805, 43442, 564, 239, 37, 499, 20755, 3966, 57, 328, 2180],
#  [17806, 73197, 43443, 2061, 17806, 20756],
#  [2485, 73198, 10, 557],
#  [195, 789, 4100, 43444, 29, 11403, 339, 73199],
#  [3546, 3375, 599, 20757, 73200, 17807, 9, 2332, 113, 93],
#  [5610, 45, 9, 73201],
#  [43445, 96, 73202, 73203, 31646, 73204, 43446, 31647, 25082],
#  [870, 350, 158, 15476, 1075, 280, 73205, 1484],
#  [43447, 73206, 73207, 222, 1, 61, 7467, 1],
#  [43448,
#   8424,
#   20758,
#   43449,
#   31648,
#   4579,
#   12530,
#   2004,
#   9665,
#   73208,
#   3458,
#   43450,
#   733,
#   6122,
#   26,
#   4929,
#   930,
#   3977,
#   73209,
#   43451,
#   34,
#   5,
#   1,
#   6386,
#   25083,
#   243,
#   76,
#   128,
#   25,
#   3078,
#   456,
#   17808,
#   780,
#   13875,
#   9666,
#   202,
#   15477],
#  [447,
#   694,
#   669,
#   2682,
#   347,
#   73210,
#   3856,
#   244,
#   2939,
#   6,
#   4101,
#   73211,
#   4101,
#   73212,
#   73213,
#   31649,
#   31650,
#   31651,
#   93,
#   531,
#   326,
#   1776,
#   12,
#   993,
#   73214,
#   20759,
#   419,
#   2027,
#   6766],
#  [471, 3647, 3131],
#  [33, 5155],
#  [194, 175, 382, 17807, 409],
#  [73215,
#   405,
#   25084,
#   43452,
#   43453,
#   3081,
#   15478,
#   3459,
#   1256,
#   84,
#   646,
#   73216,
#   6144,
#   43454,
#   813,
#   73217,
#   31652,
#   17809,
#   50,
#   2945,
#   43455],
#  [20760, 15479, 1636, 73218, 73219, 73220, 17810, 73221, 12, 2136, 73222],
#  [25085, 1289, 27, 73223, 25086, 73224, 73225, 5375, 73226, 43456, 12531, 387],
#  [5855, 15480, 73227, 31653, 73228, 73229, 31654],
#  [485, 58],
#  [1047, 948],
#  [5611,
#   73230,
#   17811,
#   73231,
#   73232,
#   31655,
#   73233,
#   25087,
#   9667,
#   17812,
#   1829,
#   73234,
#   1212,
#   17813,
#   73235,
#   17,
#   1984,
#   73236,
#   43457],
#  [8425, 73237, 73238, 16],
#  [2062, 73239, 95, 73240, 689, 73241],
#  [17814, 4, 73242],
#  [143, 20720, 1433, 25088, 1555, 73243, 1062, 45, 1528],
#  [23, 96, 2, 503, 129, 3662],
#  [47, 11404, 68],
#  [102,
#   73244,
#   73245,
#   73246,
#   248,
#   143,
#   43458,
#   2683,
#   73247,
#   31656,
#   249,
#   43459,
#   34,
#   5856,
#   31657,
#   73248,
#   5376,
#   31658,
#   43460,
#   43461,
#   43462,
#   3758,
#   608,
#   31659],
#  [5857, 17815, 3294, 43463, 25089, 1290, 1985, 118],
#  [6419, 420, 2669, 73249, 7501, 11405],
#  [36, 1],
#  [73250, 73251],
#  [43464, 73252],
#  [152, 73253, 73254, 3974, 1],
#  [73255, 16],
#  [269],
#  [65, 1506, 10465],
#  [146, 3663, 179, 119, 4761, 391, 1063],
#  [39, 247, 22, 2028],
#  [5,
#   11,
#   15,
#   73256,
#   73257,
#   474,
#   312,
#   2372,
#   3015,
#   73258,
#   9668,
#   535,
#   1331,
#   4580,
#   6394,
#   1396,
#   73259,
#   7905,
#   690],
#  [73260, 5377, 7087, 1062, 20761],
#  [232, 817],
#  [43465,
#   1529,
#   13876,
#   43466,
#   15481,
#   31660,
#   2333,
#   1190,
#   25090,
#   1925,
#   31661,
#   73261,
#   9007,
#   31662,
#   73262,
#   31663,
#   3295,
#   7906,
#   73263,
#   31664,
#   73264,
#   15482,
#   73265,
#   1530,
#   73266,
#   73267,
#   73268,
#   3367],
#  [6, 73269],
#  [3547, 31665, 2684, 25091, 73270, 5156, 2373, 656, 13877, 1, 49],
#  [3, 6145, 73271, 73272, 1699, 468, 7502, 73273, 13878],
#  [15483,
#   3548,
#   25092,
#   14,
#   73274,
#   441,
#   10466,
#   12,
#   31666,
#   12532,
#   12533,
#   253,
#   2245],
#  [3296, 46, 43467],
#  [508, 501, 285, 31667, 5157, 1261, 20762, 1980, 2334],
#  [1377, 25093, 7, 13879, 73275],
#  [1577, 73276, 4233, 1350, 43468, 907, 73277, 73278, 9008, 5858],
#  [20763, 3376, 9009, 4384, 43469, 147, 4, 20764, 1828],
#  [17816, 73279, 43470, 4, 8421, 415, 17817, 73280, 3212, 1],
#  [73281],
#  [32, 1531, 73282, 73283],
#  [6122,
#   73284,
#   315,
#   2,
#   506,
#   127,
#   73285,
#   48,
#   75,
#   10,
#   642,
#   506,
#   71,
#   7088,
#   6420,
#   73286,
#   31668,
#   45,
#   5612,
#   73287,
#   45],
#  [43471, 822, 12534, 4930, 84, 73288],
#  [73289],
#  [40,
#   2,
#   43472,
#   7907,
#   31669,
#   2210,
#   2063,
#   17818,
#   31670,
#   4405,
#   414,
#   73290,
#   2029,
#   73291,
#   20765,
#   139,
#   1155,
#   294,
#   31671,
#   1926,
#   43473,
#   482,
#   1103,
#   73292,
#   43474,
#   73293,
#   25094,
#   15484,
#   186],
#  [404, 2064, 43475, 1, 95, 5, 18, 610, 73294, 20766],
#  [25095, 31672, 25096, 20, 1],
#  [43476, 4234, 140],
#  [132, 29, 965, 126, 31673, 138, 43477, 2674],
#  [73295],
#  [25097, 34, 3857],
#  [6767, 73296, 724, 11406, 1778, 20767, 7089, 13880, 1678, 73297, 1525],
#  [15485, 73298, 3377, 73299],
#  [586, 20, 73300, 142, 70],
#  [156, 230, 73301, 992, 43478, 2421],
#  [73302, 5613, 4581, 1611, 73303, 1703, 31674],
#  [3843, 223, 565, 5158, 267, 1498, 73304, 1291, 73305, 73306],
#  [2143, 73307, 713, 196, 386, 74, 12, 21, 4, 848, 3964],
#  [9010,
#   7,
#   3858,
#   1414,
#   6421,
#   6146,
#   244,
#   3286,
#   9011,
#   73308,
#   43479,
#   73309,
#   15486,
#   31675,
#   93,
#   2952,
#   3759,
#   65,
#   73310,
#   43480,
#   20768,
#   10467,
#   7503,
#   43481,
#   73311,
#   126,
#   1161,
#   43482,
#   73312],
#  [47, 939, 19, 1230, 87],
#  [73313],
#  [31, 54, 21, 796, 17819],
#  [153, 5159, 56, 81, 3, 73314, 28, 82, 82],
#  [73315, 135, 265, 12535, 3, 73316, 2058, 818],
#  [20769, 73317, 73318, 20770],
#  [12536, 15487, 2207, 72],
#  [338, 13, 248, 264, 680, 57, 903, 5378, 61, 43483],
#  [6422, 43484, 4406, 31676, 6422, 73319, 73320, 73321],
#  [281, 73322, 17820, 2752, 62, 296, 381, 1485],
#  [6, 807, 73323, 73324, 12537, 364, 73325, 4, 6423, 73326, 6, 19, 114],
#  [4,
#   732,
#   11407,
#   43485,
#   25098,
#   73327,
#   3,
#   2,
#   110,
#   509,
#   2,
#   43486,
#   1,
#   2753,
#   3,
#   177,
#   43487,
#   4,
#   25,
#   5,
#   4102,
#   2754,
#   1160,
#   5,
#   73328,
#   30,
#   73329,
#   73330],
#  [73331, 5160],
#  [73332, 12538, 73333, 1986],
#  [33, 10468, 3460, 474, 219, 682],
#  [3978, 11408, 489, 9012, 43488],
#  [20771, 31677, 42, 73334],
#  [3368, 537, 43489],
#  [15488],
#  [73335, 73336, 16],
#  [12539, 43490, 1721, 73337],
#  [39,
#   808,
#   61,
#   2685,
#   1628,
#   115,
#   73338,
#   337,
#   5,
#   11,
#   3859,
#   500,
#   1575,
#   6147,
#   705,
#   167,
#   59,
#   680,
#   100,
#   1],
#  [323, 73339, 107, 11409],
#  [518, 264, 73340, 73341, 73342, 73343, 242, 73344, 65, 73345],
#  [80],
#  [217, 13881, 31678, 53],
#  [1575,
#   177,
#   31679,
#   73346,
#   200,
#   13882,
#   73,
#   1,
#   1497,
#   1448,
#   624,
#   73347,
#   43491,
#   1468,
#   44,
#   968,
#   9013,
#   43492,
#   43493,
#   73348],
#  [318, 73349, 21, 6148, 73350, 68, 17821, 15489, 43494, 309],
#  [5614, 74, 776, 20, 25, 142, 31680],
#  [73351],
#  [1891, 224, 1],
#  [516, 43495],
#  [6, 20772, 5161, 148, 113],
#  [1398, 17822, 2684, 31681],
#  [11410, 43, 73352, 73353, 73354],
#  [6424, 73355, 171, 9669, 7090, 73356, 73357, 157, 48, 757],
#  [73358, 97, 1, 2422, 377, 559, 1215, 12, 31682, 210],
#  [10469, 299, 73359, 264, 1146, 4407, 146, 13883, 124],
#  [4103, 2573],
#  [73360, 752, 73361, 4931, 73362, 73363, 31683],
#  [15490, 17823, 425, 2211, 73364],
#  [73365, 15491, 1332, 1613, 17824, 758, 73366, 1],
#  [2956,
#   8426,
#   1,
#   73367,
#   4085,
#   56,
#   73368,
#   7091,
#   8427,
#   1155,
#   481,
#   73369,
#   8428,
#   1,
#   20773,
#   10470,
#   884],
#  [184,
#   73370,
#   13884,
#   1367,
#   15492,
#   3549,
#   2827,
#   73371,
#   2358,
#   1469,
#   43496,
#   43497,
#   241],
#  [816, 360, 5379],
#  [9014, 5843, 1399, 1399, 13843, 1399, 1399],
#  [11411,
#   31684,
#   22,
#   72,
#   1698,
#   1507,
#   2828,
#   57,
#   6752,
#   1,
#   213,
#   31685,
#   15493,
#   43498,
#   2882],
#  [73, 13885, 73372],
#  [25099, 73373, 73374],
#  [73375, 359, 399, 15494, 73376, 3213, 1747, 791, 15495, 828, 7092, 53, 73377],
#  [430, 73378, 165, 73379, 3204, 73380, 43499, 73381, 11412, 4924],
#  [73382,
#   277,
#   73383,
#   73384,
#   516,
#   2957,
#   20774,
#   73385,
#   73386,
#   592,
#   73387,
#   25100,
#   127,
#   449,
#   398,
#   31686,
#   73388,
#   7908,
#   73389],
#  [255, 1451, 25101, 1226, 73390, 73391],
#  [4582, 73392, 43500, 20775, 25102, 15496, 4932, 2030],
#  [54,
#   180,
#   211,
#   73393,
#   43501,
#   13886,
#   43502,
#   148,
#   43503,
#   73394,
#   17,
#   25103,
#   578,
#   73395,
#   13,
#   760,
#   957,
#   9670,
#   1005,
#   3132,
#   73396,
#   154,
#   107,
#   43504],
#  [73397,
#   73398,
#   31687,
#   17825,
#   17826,
#   2486,
#   187,
#   21,
#   6768,
#   31688,
#   7093,
#   222,
#   1,
#   29,
#   17827,
#   174,
#   146,
#   5859,
#   6769,
#   73399,
#   132,
#   823,
#   383,
#   73400,
#   1,
#   31689,
#   137,
#   1,
#   73401,
#   3550,
#   73402],
#  [43505, 73403, 3196, 73404, 6770, 73405],
#  [301, 706, 25104, 73, 1508, 210],
#  [482, 43506, 2335, 350, 43507, 8, 73406, 98, 4552, 25105, 12540],
#  [3, 794, 320, 73407, 7094],
#  [238, 73408, 73409],
#  [727, 127, 73410, 73411],
#  [1587, 20, 632, 142, 2958],
#  [11413, 25106, 73412, 507, 9671, 7904],
#  [73413, 31690, 6149, 2, 541, 1378, 130, 27],
#  [4, 382, 3378, 1324, 550, 2246, 298, 862],
#  [73414, 4933, 73415],
#  [43508, 6425, 73416, 9672],
#  [43509,
#   31691,
#   7504,
#   73417,
#   73418,
#   73419,
#   73420,
#   159,
#   73421,
#   73422,
#   73423,
#   2671,
#   73424,
#   73425,
#   13,
#   73426],
#  [4,
#   30,
#   156,
#   55,
#   300,
#   26,
#   18,
#   73427,
#   73428,
#   4104,
#   73429,
#   2686,
#   2889,
#   73430,
#   73431,
#   101,
#   73432,
#   73433,
#   1368,
#   73434,
#   11414,
#   73435,
#   2,
#   25107,
#   154,
#   119,
#   73436],
#  [22, 73437],
#  [2421,
#   73438,
#   5860,
#   20776,
#   73439,
#   73440,
#   43510,
#   4583,
#   73441,
#   20777,
#   20778,
#   31692,
#   2302,
#   113,
#   414,
#   73442,
#   73443,
#   199,
#   1115,
#   1105,
#   256,
#   31693,
#   73444,
#   5380,
#   373,
#   324,
#   1103,
#   73445,
#   17828,
#   12541],
#  [73446, 7909, 73447, 13887, 9673, 25108, 73448, 391, 2247, 73449],
#  [13888, 17829, 5127, 16],
#  [1532, 7505, 250, 27, 45],
#  [1927, 36, 1],
#  [73450, 73451],
#  [31694, 55, 2097, 27],
#  [347, 73452, 12542],
#  [5162, 48, 20, 1007, 43],
#  [22, 28],
#  [311, 15497, 11415, 73453],
#  [73454, 105, 26, 1697, 9015, 12, 6771],
#  [73455],
#  [465, 4934, 9674, 25109, 1125, 17, 73456, 43511, 20779],
#  [80, 112, 1261, 571, 421, 445, 341, 4235, 994, 556, 61, 1528],
#  [17830, 73457, 73458, 31695, 174, 43512, 73459, 230, 36, 73460, 73461, 72],
#  [9016, 1198],
#  [17831, 524, 20780],
#  [1722, 252, 201, 1113, 6, 5615],
#  [6772, 1452],
#  [5163, 73462, 3214, 1155, 2212, 43513, 3860, 263, 1161, 43514, 592, 73463],
#  [70, 15498, 73464, 76, 73465],
#  [2423, 5159, 42, 346, 90, 12543, 43515, 13889, 1961, 7506, 7095, 1045, 113],
#  [562, 706, 31696],
#  [942, 73466, 14, 4763, 772, 84, 636, 525],
#  [20781, 17832, 2478, 73467],
#  [857, 25110, 20782, 9675, 2031, 8429, 4584, 1113, 238, 1079],
#  [2248, 31697, 581, 5, 11, 643],
#  [9676,
#   17833,
#   73468,
#   10471,
#   7910,
#   3664,
#   12544,
#   31698,
#   25111,
#   6150,
#   10472,
#   5,
#   18,
#   4,
#   2143],
#  [465, 7911],
#  [6773, 25112, 3082],
#  [73469],
#  [4, 13, 79, 330],
#  [217, 73470, 31699, 25113, 31700, 43516],
#  [568, 483, 259, 1071, 1777, 1287, 9677, 166, 1],
#  [90, 4105, 703, 1, 73471, 1274, 73472, 5616],
#  [32,
#   31,
#   577,
#   31,
#   310,
#   4746,
#   2620,
#   73473,
#   1191,
#   15499,
#   418,
#   995,
#   4101,
#   885,
#   12,
#   73474,
#   12545,
#   73475,
#   2065,
#   73476,
#   5381,
#   15500,
#   25114,
#   73477,
#   73478,
#   1292,
#   20783,
#   73479,
#   73480,
#   13890,
#   73481,
#   9678],
#  [2098,
#   43517,
#   43518,
#   5366,
#   5617,
#   878,
#   1,
#   29,
#   3379,
#   132,
#   17834,
#   73482,
#   146,
#   2475],
#  [282, 7, 43519, 47, 73483],
#  [73484, 20784, 2, 73485, 484, 146, 1116, 2236, 326, 20785, 43520, 5839],
#  [858, 3380, 73486, 2424, 73487],
#  [2249, 73488, 6426, 102, 12546],
#  [4935,
#   11416,
#   6,
#   949,
#   73489,
#   13891,
#   402,
#   9679,
#   141,
#   5861,
#   761,
#   181,
#   4585,
#   1351,
#   2755,
#   2172,
#   73490,
#   33,
#   2,
#   43521,
#   43522],
#  [3979, 206, 1126, 238, 46],
#  [4, 116, 229, 13892, 170, 73491, 73492, 73493],
#  [429, 73494, 274],
#  [32, 6774, 3980, 2959, 73495, 160, 160],
#  [35, 73496, 73497, 73498],
#  [43523, 73499, 20786],
#  [2, 73500, 10473, 684, 41, 94, 11417],
#  [681, 195, 377, 1960, 6427, 1555],
#  [25115, 740, 73501, 57, 4227, 3297, 92, 356, 308, 817, 6428, 1828],
#  [89, 526, 73502, 31701],
#  [9017, 109],
#  [73503, 2362, 695, 13893, 219, 17835, 1],
#  [662, 5862, 349, 567, 975, 8429, 1275, 73504, 1416, 7507, 13, 4399],
#  [4408,
#   4936,
#   73505,
#   13,
#   2066,
#   22,
#   3187,
#   25116,
#   25117,
#   11418,
#   73506,
#   5164,
#   5618,
#   2024],
#  [73507, 2425, 2425, 25118],
#  [17836, 25119, 13894, 668, 1293, 12547, 253, 27],
#  [2426, 1, 22, 333],
#  [73508],
#  [839, 7505, 276, 73509, 276, 26, 43524, 15501],
#  [92, 31702, 44, 73510, 3981, 342, 2, 365],
#  [685, 15502, 120, 831, 477, 5, 530],
#  [31, 983, 271, 1470, 57, 73511, 73512, 51],
#  [10474],
#  [454, 447, 16],
#  [194, 58, 73513, 276, 31703, 41, 94, 3215, 73514, 196, 550],
#  [372, 745, 21, 1, 41, 94, 1080, 110, 246],
#  [25120,
#   25121,
#   2144,
#   13,
#   73515,
#   117,
#   4236,
#   150,
#   286,
#   9680,
#   1417,
#   1417,
#   73516,
#   73517,
#   249,
#   1],
#  [2250, 2032],
#  [117, 2, 1025, 28, 43, 668, 38, 362, 141, 128, 11419],
#  [8430, 73518, 73519],
#  [392,
#   365,
#   15503,
#   73520,
#   73521,
#   73522,
#   73523,
#   188,
#   574,
#   1136,
#   1183,
#   73524,
#   43525,
#   11420,
#   73525,
#   3760,
#   1164,
#   1231],
#  [88, 17837, 31704, 73526, 755, 8431, 73527, 157, 48, 198, 28],
#  [453, 31705, 289, 43526, 575, 119, 575, 3744, 73528, 890],
#  [73529, 93, 950, 4, 130, 181, 156, 1048],
#  [171],
#  [698, 73530, 73531, 43527],
#  [12548, 73532, 1399],
#  [10475],
#  [17838, 8432, 260, 73533],
#  [73534, 73535],
#  [131, 10476, 31706, 43528, 73536, 620, 13895],
#  [29, 2212, 46, 64, 73537, 2181, 2136, 4237, 8433],
#  [43529, 73538, 43529, 73539, 73540, 65, 7096, 73541],
#  [1684, 73542, 1834],
#  [191, 502, 2132],
#  [20787, 73543, 2, 274],
#  [73544, 73545, 983, 73546],
#  [73547,
#   73548,
#   48,
#   20788,
#   73549,
#   17,
#   11421,
#   7,
#   707,
#   73550,
#   31707,
#   31708,
#   73551,
#   20789],
#  [2133, 73552, 73553, 24, 10477, 31709],
#  [275, 3551, 98, 9681, 2213, 7912, 320, 31710, 100, 1685, 27],
#  [3298, 73554, 217, 53],
#  [73555, 73556, 384, 829, 73557],
#  [25122,
#   11422,
#   73558,
#   31711,
#   25123,
#   73559,
#   231,
#   25124,
#   73560,
#   73561,
#   600,
#   339],
#  [3, 54, 2890, 73562, 31712, 38, 2, 2960, 168],
#  [73, 4586, 25125, 516, 65, 1182, 73563],
#  [86, 3299, 23, 173, 73564],
#  [942, 73565, 6429, 31713],
#  [99, 13896, 2025, 56, 15, 1005],
#  [43530, 73566, 95, 73567, 20790, 73568, 51],
#  [73569, 73570],
#  [73571, 73572],
#  [7913, 31714, 20, 31715, 11423, 2574, 153, 73573, 81, 153, 175, 1418, 382],
#  [2954,
#   2682,
#   5,
#   1,
#   13897,
#   73574,
#   73575,
#   35,
#   43531,
#   73576,
#   4,
#   1432,
#   1081,
#   1411,
#   73577,
#   17839,
#   73578,
#   73579,
#   17,
#   73580,
#   4,
#   73581,
#   17840],
#  [73582, 73583, 4759, 5382, 73584, 73585, 4238, 550, 1637, 3461, 143, 3665],
#  [96, 1021, 43532],
#  [1547, 17721, 1350, 73586, 24954, 24955],
#  [73587,
#   73588,
#   73589,
#   43,
#   17841,
#   823,
#   832,
#   38,
#   31,
#   1464,
#   73590,
#   11424,
#   181,
#   73591,
#   75,
#   10,
#   280,
#   26,
#   73592],
#  [73593, 5165, 73594],
#  [25126, 12549, 306, 2517, 1659, 25127, 13892, 2033, 12550, 42, 17842, 73595],
#  [7, 944, 196, 10, 1704],
#  [6430, 1045, 72, 73596, 73597],
#  [5863, 234, 73598],
#  [35, 282, 65, 9682],
#  [73599, 13898, 73600, 73601, 24, 4937, 130, 924, 3552, 3552, 63, 436],
#  [31716, 612],
#  [1013, 73602, 802, 434, 31717, 4764, 25, 9683, 43533, 8434, 4764, 1379],
#  [73603, 1117, 262],
#  [2374, 1116, 2, 827, 73604, 8435],
#  [4409, 879, 815],
#  [616,
#   73605,
#   652,
#   13899,
#   17,
#   1750,
#   73606,
#   73607,
#   191,
#   4,
#   73608,
#   73609,
#   73610,
#   73611,
#   15504,
#   73612,
#   73613,
#   73614,
#   31,
#   73615],
#  [1798, 43534, 1351, 145, 25128, 4587, 20791, 4765, 4, 43535],
#  [1501, 8436, 73616, 1352, 1477, 1614, 43536, 15505, 4410],
#  [4588, 73617],
#  [1026],
#  [4, 710, 43537, 3861, 458, 255, 1653, 43538, 73, 1833, 73618, 37],
#  [663, 746, 1592],
#  [3462,
#   5619,
#   31718,
#   1,
#   153,
#   31719,
#   8437,
#   31720,
#   73619,
#   73620,
#   73621,
#   1020,
#   222,
#   19,
#   31721,
#   43539,
#   17,
#   19,
#   337,
#   73622,
#   73623,
#   73624,
#   1775,
#   153,
#   4396,
#   544],
#  [76, 618, 1962, 457],
#  [20792, 73625, 25129, 140, 102, 43540],
#  [73626, 5383, 148, 73627, 15506, 849, 539, 73628],
#  [51, 269],
#  [5166, 47, 3300, 31722, 73629, 20, 73630, 73631, 73632, 73633],
#  [118, 378, 2292, 7914, 15507],
#  [644, 5384, 1310, 31723, 7915],
#  [43541, 31724, 29, 11425, 168],
#  [1041,
#   1434,
#   1116,
#   2829,
#   4106,
#   25130,
#   1019,
#   31725,
#   1170,
#   12,
#   31726,
#   220,
#   261,
#   25131,
#   41,
#   415,
#   1461,
#   521,
#   17,
#   20793,
#   73634,
#   531],
#  [43, 10478, 83, 744, 15508, 13900, 28, 3463, 72],
#  [328, 414, 2961, 74, 106],
#  [4239, 9684, 8438, 5, 1008, 15, 79, 253, 3464],
#  [784, 3553, 11, 6151, 7, 1163, 12, 20794],
#  [7916,
#   73635,
#   13901,
#   4766,
#   1326,
#   423,
#   2336,
#   4107,
#   73636,
#   7508,
#   650,
#   17843,
#   73637,
#   27,
#   741,
#   353,
#   73638,
#   73639,
#   166,
#   2332,
#   284],
#  [1894, 73640, 774],
#  [519, 13902, 43542, 73641, 1171, 15509, 20, 260, 1, 115, 45],
#  [9685, 3083, 99, 73642],
#  [31727,
#   73643,
#   655,
#   2943,
#   3381,
#   73644,
#   1058,
#   4240,
#   92,
#   73645,
#   34,
#   2248,
#   31728,
#   73646,
#   10479],
#  [31729, 1578, 2, 43543],
#  [43544, 73647, 2942, 25132, 25133, 258],
#  [25134, 3666],
#  [73648, 3667, 40, 20795],
#  [31730, 13903, 1248, 174, 15510, 73649, 73650, 2621, 73651],
#  [499,
#   225,
#   12551,
#   15511,
#   25135,
#   43545,
#   33,
#   15,
#   77,
#   5620,
#   1471,
#   13904,
#   20796,
#   17844,
#   8,
#   20797,
#   12552,
#   11426,
#   9,
#   41,
#   216,
#   31731,
#   73652,
#   20798,
#   11427,
#   849,
#   9686,
#   578,
#   4938,
#   25136,
#   6,
#   12551,
#   1182,
#   73653],
#  ...]

# %%
# max_len = max(len(item) for item in x_train)  # 59


from tensorflow.keras.preprocessing.sequence import pad_sequences
x_train_new = pad_sequences(x_train, maxlen=50)

# %%
x_train_new
# Out:
# array([[     0,      0,      0, ...,      4,   6727,   1097],
#        [     0,      0,      0, ...,  72134,   7052,  31482],
#        [     0,      0,      0, ...,      0,      0,  72135],
#        ...,
#        [     0,      0,      0, ...,  41414, 296310,  20652],
#        [     0,      0,      0, ...,  32989,  70622,  14196],
#        [     0,      0,      0, ...,    136,   2105,      1]])

# %%
x_train_new.shape, y_train.shape
# Out:
# ((150000, 50), (150000,))

# %%
vocab_size = len(tokenizer.word_index) + 1

import tensorflow as tf
from tensorflow.keras import layers
model = tf.keras.Sequential([
layers.Embedding(vocab_size, 64),  # input = vocabulary 갯수(word_index)
layers.Bidirectional(layers.LSTM(64, return_sequences=True)),  # return, true 옵션을 줘야 밑에가 받을 수 있음
layers.Bidirectional(layers.LSTM(64, return_sequences=True)),
layers.Dense(64, activation='relu'),
layers.Dense(1)])
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
              optimizer=tf.keras.optimizers.Adam(lr=1e-4), 
              metrics=['accuracy'])

hist = model.fit(x_train_new, y_train, epochs=2)
# Out:
# Epoch 1/2
# 4688/4688 [==============================] - 1136s 242ms/step - loss: 0.5479 - accuracy: 0.7149
# Epoch 2/2
# 4688/4688 [==============================] - 1145s 244ms/step - loss: 0.3319 - accuracy: 0.8757

# %%
x_test
# Out:
# array(['굳 ㅋ', 'GDNTOPCLASSINTHECLUB',
#        '뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아', ...,
#        '그림도 좋고 완성도도 높았지만... 보는 내내 불안하게 만든다',
#        '절대 봐서는 안 될 영화.. 재미도 없고 기분만 잡치고.. 한 세트장에서 다 해먹네', '마무리는 또 왜이래'],
#       dtype='<U144')

# %%
# x_test를 model.evaluate() 해주기 위해
# 문자로 이루어진 x_test를 사전에 맞게 숫자로 변환하고 데이타를 넣어주어야 함
# 그러나 x_test가 이미 list, numpy로 변환된 형태임
# 사전은 train된 것으로 사용하기 때문에 이 과정은 넘어간다.

# x_test = x_test.values.tolist()

# import numpy as np
# x_test = np.array(x_test)

from tensorflow.keras.preprocessing.text import Tokenizer
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(x_test) # 이미 list 형태이기 때문에 또 하지 않는다.
# tokenizer.word_index  # 사전 vocabulary 만들기
x_test = tokenizer.texts_to_sequences(x_test)
# 사전에 맞게 한글로 된 단어를 인덱스에 따라 숫자로 변환해 주는 작업 

from tensorflow.keras.preprocessing.sequence import pad_sequences
x_test_new = pad_sequences(x_test, maxlen=50)
# 숫자를 맞춰주는 작업

# %%
model.evaluate(x_test_new, y_test)
# Out:
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.4229 - accuracy: 0.8228
# [0.42285239696502686, 0.8227962255477905]

# %%
y_pred = model.predict(x_test_new)

# %%
y_pred
# Out:
# array([[[0.88855165],
#         [0.9115804 ],
#         [0.92934734],
#         ...,
#         [1.0175653 ],
#         [1.0093063 ],
#         [0.94305784]],
#
#        [[0.6817191 ],
#         [0.69705313],
#         [0.7067278 ],
#         ...,
#         [0.43520907],
#         [0.41959926],
#         [0.40359375]],
#
#        [[0.06376516],
#         [0.06942969],
#         [0.07322747],
#         ...,
#         [0.08980853],
#         [0.09471019],
#         [0.09076453]],
#
#        ...,
#
#        [[0.8736631 ],
#         [0.8960092 ],
#         [0.9127229 ],
#         ...,
#         [0.8252847 ],
#         [0.80504113],
#         [0.77377445]],
#
#        [[0.05201251],
#         [0.05644093],
#         [0.0590201 ],
#         ...,
#         [0.06382162],
#         [0.0677912 ],
#         [0.0676529 ]],
#
#        [[0.35047594],
#         [0.36202398],
#         [0.3674292 ],
#         ...,
#         [0.35102963],
#         [0.36297873],
#         [0.3511834 ]]], dtype=float32)

# %%
y_test
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
# 5        1
# 6        0
# 7        0
# 8        0
# 9        1
# 10       1
# 11       0
# 12       1
# 13       1
# 14       0
# 15       1
# 16       1
# 17       0
# 18       1
# 19       0
# 20       1
# 21       0
# 22       1
# 23       1
# 24       0
# 25       1
# 26       1
# 27       1
# 28       0
# 29       1
#         ..
# 49970    1
# 49971    1
# 49972    0
# 49973    0
# 49974    0
# 49975    0
# 49976    0
# 49977    0
# 49978    1
# 49979    0
# 49980    1
# 49981    1
# 49982    1
# 49983    0
# 49984    0
# 49985    1
# 49986    1
# 49987    1
# 49988    0
# 49989    0
# 49990    0
# 49991    1
# 49992    1
# 49993    1
# 49994    1
# 49995    1
# 49996    0
# 49997    0
# 49998    0
# 49999    0
# Name: label, Length: 50000, dtype: int64

# %%
y_pred[0], len(y_pred[0])
# Out:
# (array([[0.88855165],
#         [0.9115804 ],
#         [0.92934734],
#         [0.94294155],
#         [0.9532993 ],
#         [0.9611904 ],
#         [0.9672268 ],
#         [0.97188115],
#         [0.9755092 ],
#         [0.97837234],
#         [0.9806561 ],
#         [0.9824886 ],
#         [0.98395383],
#         [0.98510224],
#         [0.9859604 ],
#         [0.9865363 ],
#         [0.9868254 ],
#         [0.9868135 ],
#         [0.98647934],
#         [0.9857969 ],
#         [0.9845916 ],
#         [0.98253626],
#         [0.9799984 ],
#         [0.976943  ],
#         [0.9733344 ],
#         [0.9697765 ],
#         [0.9690484 ],
#         [0.9678517 ],
#         [0.96623164],
#         [0.9665993 ],
#         [0.96769714],
#         [0.9686431 ],
#         [0.96944946],
#         [0.97009146],
#         [0.9703807 ],
#         [0.9704738 ],
#         [0.97036374],
#         [0.9728392 ],
#         [0.98053795],
#         [0.9881898 ],
#         [0.99565786],
#         [1.0038519 ],
#         [1.011554  ],
#         [1.017623  ],
#         [1.022416  ],
#         [1.0265054 ],
#         [1.0262239 ],
#         [1.0175653 ],
#         [1.0093063 ],
#         [0.94305784]], dtype=float32), 50)

# %%
# evaluate(test)

# predict
# 하나 완전히 완료되고 확인끝나면

# 다른 하나의 set을 만들어서 
# x 에 대해 cleansing 작업 따로 하기

# %%
model.input
# Out:
# <tf.Tensor 'embedding_7_input:0' shape=(None, None) dtype=float32>

# %%
model.output
# Out:
# <tf.Tensor 'dense_15/Identity:0' shape=(None, None, 1) dtype=float32>

# %% [markdown]
# # LSTM with Time series forecasting

# %%
import tensorflow as tf 
_URI='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip'
csv_path = tf.keras.utils.get_file("./climate.csv", origin=url)  
csv_path

df = pd.read_csv('./datasets/jena_climate_2009_2016.csv')
features = df[['p (mbar)','T (degC)','rho (g/m**3)']]; 
features.index = df['Date Time'];
dataset = features.values; target = df['T (degC)'].values;
target_size = 72; 
x_train, y_train = list(), list();

for i in range(720, len(dataset) - target_size):
    indices = range(i-720, i, 6) # 레코드 720개씩 잘라냄
    x_train.append(dataset[indices])
    y_train.append(target[i:i+target_size])
    x_train = np.array(x_train); y_train = np.array(y_train);
# 날짜 순서로 되어있기 때문에 시계열 모양으로 720씩
# 전날의 데이타가 다음날에 영향을 준다는 전제하에

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(32, input_shape=x_train.shape[1:])) # (120,3): 3은 컬럼의 갯수
model.add(tf.keras.layers.LSTM(16, activation='relu'))
model.add(tf.keras.layers.Dense(target_size))
model.compile(optimizer='rms', loss='mae')

hist = model.fit(x_train, y_train, epochs=2)

pred = model.predict(x_train)

# %%
STEP = 6
def multi_step_plot(history, true_future, prediction):
    # plt.figure(figsize=(12, 6))
    num_in = list(range(-len(history), 0))
    num_out = len(true_future)
    plt.plot(num_in, np.array(history[:, 1]), label='History')
    plt.plot(np.arange(num_out)/STEP, 
             np.array(true_future), 'bx',
             label='True Future')
    if prediction.any():
        plt.plot(np.arange(num_out)/STEP, 
                 np.array(prediction), 'ro',
                 label='Predicted Future')
        plt.legend(loc='upper left')
        plt.show()

# %%
multi_step_plot(x_train[6], y_train[6], pred[6])
