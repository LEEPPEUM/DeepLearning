# %% [markdown]
# # Walmart 판매량 예측

# %% [markdown]
# - train data : 품목별로 날짜에 따른 판매량 기록.

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\user\\downloads\\downloads'

# %%
import pandas as pd
sales_train_validation = pd.read_csv('./m5-forecasting-accuracy/sales_train_validation.csv') 
sales_train_evaluation = pd.read_csv('./m5-forecasting-accuracy/sales_train_evaluation.csv') 
calendar = pd.read_csv('./m5-forecasting-accuracy/calendar.csv') 
sell_prices = pd.read_csv('./m5-forecasting-accuracy/sell_prices.csv')

# %%
sales_train_validation
# d_1 ~ d_1913 까지의 데이타가 존재
# 다음의 d_1914 ~ d_1941 28일 동안의 데이타를 예측해야 함
# Out:
#                                   id        item_id    dept_id   cat_id  \
# 0      HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 1      HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2      HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 3      HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 4      HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# 5      HOBBIES_1_006_CA_1_validation  HOBBIES_1_006  HOBBIES_1  HOBBIES
# 6      HOBBIES_1_007_CA_1_validation  HOBBIES_1_007  HOBBIES_1  HOBBIES
# 7      HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1  HOBBIES
# 8      HOBBIES_1_009_CA_1_validation  HOBBIES_1_009  HOBBIES_1  HOBBIES
# 9      HOBBIES_1_010_CA_1_validation  HOBBIES_1_010  HOBBIES_1  HOBBIES
# 10     HOBBIES_1_011_CA_1_validation  HOBBIES_1_011  HOBBIES_1  HOBBIES
# 11     HOBBIES_1_012_CA_1_validation  HOBBIES_1_012  HOBBIES_1  HOBBIES
# ...

# %%
sales_train_evaluation.head()
# d_1 ~ d_1941 까지의 데이타가 존재
# 이는 sale_train_validation의 데이타에서 28일 후의 데이타까지 합쳐진 데이타.
# 여기에서 d_1914 ~ d_1941 데이타는 예측이 아닌 실제 판매량(y_test)
# 위의 validation 데이타를 통해 모델링하여 예측량(y_pred)을 구하고 실제 판매량(y_test)과 비교해보면 정확도 등을 알 수 있음
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_evaluation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_evaluation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_evaluation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_evaluation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1932  d_1933  d_1934  d_1935  d_1936  \
# 0       CA    0    0    0    0  ...       2       4       0       0       0
# 1       CA    0    0    0    0  ...       0       1       2       1       1
# 2       CA    0    0    0    0  ...       1       0       2       0       0
# 3       CA    0    0    0    0  ...       1       1       0       4       0
# 4       CA    0    0    0    0  ...       0       0       0       2       1
#
#    d_1937  d_1938  d_1939  d_1940  d_1941
# ...

# %%
calendar
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 0     2011-01-29     11101   Saturday     1      1  2011     d_1
# 1     2011-01-30     11101     Sunday     2      1  2011     d_2
# 2     2011-01-31     11101     Monday     3      1  2011     d_3
# 3     2011-02-01     11101    Tuesday     4      2  2011     d_4
# 4     2011-02-02     11101  Wednesday     5      2  2011     d_5
# 5     2011-02-03     11101   Thursday     6      2  2011     d_6
# 6     2011-02-04     11101     Friday     7      2  2011     d_7
# 7     2011-02-05     11102   Saturday     1      2  2011     d_8
# 8     2011-02-06     11102     Sunday     2      2  2011     d_9
# 9     2011-02-07     11102     Monday     3      2  2011    d_10
# 10    2011-02-08     11102    Tuesday     4      2  2011    d_11
# 11    2011-02-09     11102  Wednesday     5      2  2011    d_12
# 12    2011-02-10     11102   Thursday     6      2  2011    d_13
# ...

# %%
sell_prices
# Out:
#         store_id        item_id  wm_yr_wk  sell_price
# 0           CA_1  HOBBIES_1_001     11325        9.58
# 1           CA_1  HOBBIES_1_001     11326        9.58
# 2           CA_1  HOBBIES_1_001     11327        8.26
# 3           CA_1  HOBBIES_1_001     11328        8.26
# 4           CA_1  HOBBIES_1_001     11329        8.26
# 5           CA_1  HOBBIES_1_001     11330        8.26
# 6           CA_1  HOBBIES_1_001     11331        8.26
# 7           CA_1  HOBBIES_1_001     11332        8.26
# 8           CA_1  HOBBIES_1_001     11333        8.26
# 9           CA_1  HOBBIES_1_001     11334        8.26
# 10          CA_1  HOBBIES_1_001     11335        8.26
# 11          CA_1  HOBBIES_1_001     11336        8.26
# 12          CA_1  HOBBIES_1_001     11337        8.26
# 13          CA_1  HOBBIES_1_001     11338        8.26
# 14          CA_1  HOBBIES_1_001     11339        8.26
# 15          CA_1  HOBBIES_1_001     11340        8.26
# ...

# %% [markdown]
# ## sales_train_validation만을 이용하여 판매량 예측
# ### SQL이용

# %%
import sqlite3
conn = sqlite3.connect('walmart.db')
sales_train_validation.to_sql('train', conn, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-11-097bb935cabb> in <module>
#       1 import sqlite3
#       2 conn = sqlite3.connect('walmart.db')
# ----> 3 sales_train_validation.to_sql('train', conn, if_exists='replace')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
# ...

# %%
# SQL 최대 컬럼 수가 999개이므로 SQLITE로 작업 불가.
# sqlite와 같은 관계형 데이터베이스 RDB가 아닌
# MongoDB와 같은 No-SQL을 이용해야 이렇게 많은 컬럼 수를 처리할 수 있음.

# %% [markdown]
# # LSTM with Time series forecasting
# 예제

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\user\\downloads\\downloads'

# %%
import tensorflow as tf 
_URI='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip'
csv_path = tf.keras.utils.get_file("./climate.zip", origin=_URI)  
csv_path
# Out:
# ...
# 13574144/13568290 [==============================] - 3s 0us/step
# 'C:\\Users\\user\\.keras\\datasets\\./climate.zip'

# %%
import zipfile        
fantasy_zip = zipfile.ZipFile(csv_path)
fantasy_zip.extractall('./')
fantasy_zip.close()

# %%
df = pd.read_csv('./jena_climate_2009_2016.csv')
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
features = df[['p (mbar)','T (degC)','rho (g/m**3)']]; 
features.index = df['Date Time'];
dataset = features.values; 
target = df['T (degC)'].values;
target_size = 72;

# %%
features.head()
# Out:
#                      p (mbar)  T (degC)  rho (g/m**3)
# Date Time
# 01.01.2009 00:10:00    996.52     -8.02       1307.75
# 01.01.2009 00:20:00    996.57     -8.41       1309.80
# 01.01.2009 00:30:00    996.53     -8.51       1310.24
# 01.01.2009 00:40:00    996.51     -8.31       1309.19
# 01.01.2009 00:50:00    996.51     -8.27       1309.00

# %%
dataset, len(dataset)
# Out:
# (array([[ 996.52,   -8.02, 1307.75],
#         [ 996.57,   -8.41, 1309.8 ],
#         [ 996.53,   -8.51, 1310.24],
#         ...,
#         [ 999.82,   -3.16, 1288.39],
#         [ 999.81,   -4.23, 1293.56],
#         [ 999.82,   -4.82, 1296.38]]),
#  420551)

# %%
target
# Out:
# array([-8.02, -8.41, -8.51, ..., -3.16, -4.23, -4.82])

# %%
x_train.shape, y_train.shape
# Out:
# ((419759, 120, 3), (419759, 72))

# %%
target_size = 72;
x_train, y_train = list(), list();
for i in range(720, len(dataset) - target_size):
    indices = range(i-720, i, 6) # 레코드 720개씩 잘라냄
    x_train.append(dataset[indices])
    y_train.append(target[i:i+target_size])
    
import numpy as np    
x_train = np.array(x_train); 
y_train = np.array(y_train);
# 날짜 순서로 되어있기 때문에 시계열 모양으로 720씩
# 전날의 데이타가 다음날에 영향을 준다는 전제하에

# %%
import tensorflow as tf
from tensorflow.keras import layers
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(32, input_shape=x_train.shape[1:], 
                               return_sequences=True)) # (120,3): 3은 컬럼의 갯수
model.add(tf.keras.layers.LSTM(16, activation='relu'))
model.add(tf.keras.layers.Dense(target_size))
model.compile(optimizer='RMSprop', loss='mae')

hist = model.fit(x_train, y_train, epochs=2)

pred = model.predict(x_train)
# Out:
# Epoch 1/2
# 13118/13118 [==============================] - 1456s 111ms/step - loss: 552.5943
# Epoch 2/2
# 13118/13118 [==============================] - 1474s 112ms/step - loss: 3.0656

# %%
STEP = 6 # ?

import matplotlib.pyplot as plt
def multi_step_plot(history, true_future, prediction):
    # plt.figure(figsize=(12, 6))
    num_in = list(range(-len(history), 0))
    num_out = len(true_future)
    plt.plot(num_in, np.array(history[:, 1]), label='History')
    plt.plot(np.arange(num_out)/STEP, 
             np.array(true_future), 'bx',
             label='True Future')
    if prediction.any():
        plt.plot(np.arange(num_out)/STEP, 
                 np.array(prediction), 'ro',
                 label='Predicted Future')
    plt.legend(loc='upper left')
    plt.show()

# %%
multi_step_plot(x_train[6], y_train[6], pred[6])

# %% [markdown]
# LSTM을 이용하여 품목별로 추세선을 긋고\
# 모델을 만들때 28개씩 나누어주면 \
# 그 다음에 필요한 28일 간의 예측 추세선을 얻을 수 있다.
# - 우선 첫번째 레코드, 첫번째 품목을 가지고 모델링하여 추세선을 얻을 수 있으면, 다른 것은 for문 돌리면 됨

# %%
multi_step_plot(x_train[419758], y_train[419758], pred[419758])
